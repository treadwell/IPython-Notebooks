# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 2: Mining Facebook: Analyzing Fan Pages, Examining Friendships, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Facebook API Access
#
# Facebook implements OAuth 2.0 as its standard authentication mechanism, but provides a convenient way for you to get an _access token_ for development purposes, and we'll opt to take advantage of that convenience in this notebook. For details on implementing an OAuth flow with Facebook (all from within IPython Notebook), see the \_AppendixB notebook from the [IPython Notebook Dashboard](/).
#
# For this first example, login to your Facebook account and go to https://developers.facebook.com/tools/explorer/ to obtain and set permissions for an access token that you will need to define in the code cell defining the ACCESS_TOKEN variable below.
#
# Be sure to explore the permissions that are available by clicking on the "Get Access Token" button that's on the page and exploring all of the tabs available. For example, you will need to set the "friends_likes" option under the "Friends Data Permissions" since this permission is used by the script below but is not a basic permission and is not enabled by default.
#
# <img src="files/resources/ch02-facebook/images/FB_GraphExplorer_perms.png" width="300px" /><br />

# %%
# Copy and paste in the value you just got from the inline frame into this variable and execute this cell.
# Keep in mind that you could have just gone to https://developers.facebook.com/tools/access_token/
# and retrieved the "User Token" value from the Access Token Tool

ACCESS_TOKEN = 'CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD'

# %% [markdown]
# ## Example 1. Making Graph API requests over HTTP

# %%
import requests # pip install requests
import json

base_url = 'https://graph.facebook.com/me'

# Get 10 likes for 10 friends
fields = 'id,name,friends.limit(10).fields(likes.limit(10))'

url = '%s?fields=%s&access_token=%s' % \
    (base_url, fields, ACCESS_TOKEN,)

# This API is HTTP-based and could be requested in the browser,
# with a command line utlity like curl, or using just about
# any programming language by making a request to the URL.
# Click the hyperlink that appears in your notebook output
# when you execute this code cell to see for yourself...
print url

# Interpret the response as JSON and convert back
# to Python data structures
content = requests.get(url).json()

# Pretty-print the JSON and display it
print json.dumps(content, indent=1)
# Out:
# https://graph.facebook.com/me?fields=id,name,friends.limit(10).fields(likes.limit(10))&access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD
# {
#  "friends": {
#   "paging": {
#    "next": "https://graph.facebook.com/630308116/friends?limit=10&fields=likes.redirect%28false%29.limit%2810%29&access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&offset=10&__after_id=500027746"
#   },
#   "data": [
#    {
#     "id": "18834",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTExMjUzMTU5NjA5",
#        "before": "ODQ5MTc2ODgzNzE="
#       },
#       "next": "https://graph.facebook.com/18834/likes?limit=10&access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&after=MTExMjUzMTU5NjA5"
#      },
#      "data": [
#       {
#        "category": "Tv network",
#        "created_time": "2013-01-11T13:03:32+0000",
#        "name": "Cartoon Network",
#        "id": "84917688371"
#       },
#       {
#        "category": "News/media website",
#        "created_time": "2012-08-07T10:42:00+0000",
#        "name": "Bleacher Report",
#        "category_list": [
#         {
#          "id": "2709",
#          "name": "News/Media Website"
#         }
#        ],
#        "id": "7331091005"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2012-02-11T20:08:34+0000",
#        "name": "The Naismith Trophy",
#        "id": "220184541407323"
#       },
#       {
#        "category": "Professional sports team",
#        "created_time": "2011-05-19T21:40:09+0000",
#        "name": "Ryder Cup Team USA",
#        "category_list": [
#         {
#          "id": "1801",
#          "name": "Professional Sports Team"
#         }
#        ],
#        "id": "147539111966451"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2011-03-28T20:35:08+0000",
#        "name": "PGA Championship",
#        "category_list": [
#         {
#          "id": "2603",
#          "name": "Non-Profit Organization"
#         }
#        ],
#        "id": "167664346600152"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2011-02-05T02:28:01+0000",
#        "name": "NCAA Men's Basketball March Madness",
#        "id": "176134773759"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2010-12-21T00:50:09+0000",
#        "name": "NCAA",
#        "category_list": [
#         {
#          "id": "2603",
#          "name": "Non-Profit Organization"
#         }
#        ],
#        "id": "13950081604"
#       },
#       {
#        "category": "Professional sports team",
#        "created_time": "2010-10-05T10:08:10+0000",
#        "name": "The Presidents Cup",
#        "category_list": [
#         {
#          "id": "192119584190796",
#          "name": "Event"
#         },
#         {
#          "id": "176059775772759",
#          "name": "Golf Course"
#         }
#        ],
#        "id": "112905282057051"
#       },
#       {
#        "category": "News/media website",
#        "created_time": "2010-10-04T00:24:28+0000",
#        "name": "Pack Pride",
#        "id": "80172665859"
#       },
#       {
#        "category": "Media/news/publishing",
#        "created_time": "2010-08-04T16:00:37+0000",
#        "name": "Time Warner",
#        "id": "111253159609"
#       }
#      ]
#     }
#    },
#    {
#     "id": "317552"
#    },
#    {
#     "id": "1102512"
#    },
#    {
#     "id": "4904172"
#    },
#    {
#     "id": "5615484",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTgyNTI3MTcxODY3MDAw",
#        "before": "NDI5MDc2OTYwNTQyNjcz"
#       },
#       "next": "https://graph.facebook.com/5615484/likes?limit=10&access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&after=MTgyNTI3MTcxODY3MDAw"
#      },
#      "data": [
#       {
#        "category": "Musician/band",
#        "created_time": "2013-09-24T13:20:04+0000",
#        "name": "Tom Gallo",
#        "id": "429076960542673"
#       },
#       {
#        "category": "Book",
#        "created_time": "2013-02-27T02:40:15+0000",
#        "name": "East of Eden",
#        "id": "108101129217451"
#       },
#       {
#        "category": "Book",
#        "created_time": "2013-02-27T02:40:05+0000",
#        "name": "Ready Player One",
#        "id": "237670989612126"
#       },
#       {
#        "category": "Movie",
#        "created_time": "2013-01-08T23:01:21+0000",
#        "name": "My Dinner with Andre",
#        "id": "103998332970926"
#       },
#       {
#        "category": "Radio station",
#        "created_time": "2012-12-13T18:44:44+0000",
#        "name": "Themashupradio.com",
#        "id": "205387572834401"
#       },
#       {
#        "category": "Health/medical/pharmacy",
#        "created_time": "2012-11-19T20:50:08+0000",
#        "name": "Peter Breen Family Dentistry",
#        "category_list": [
#         {
#          "id": "174187662626299",
#          "name": "Dentist"
#         }
#        ],
#        "id": "237712509684816"
#       },
#       {
#        "category": "Book",
#        "created_time": "2012-10-15T13:11:32+0000",
#        "name": "The Lord of the Rings",
#        "id": "271216762999421"
#       },
#       {
#        "category": "Entertainment website",
#        "created_time": "2012-05-01T17:49:53+0000",
#        "name": "Incredibox [ Official ]",
#        "id": "182619895103489"
#       },
#       {
#        "category": "Community",
#        "created_time": "2012-04-05T12:51:28+0000",
#        "name": "Team EVA",
#        "id": "223963567711425"
#       },
#       {
#        "category": "Other",
#        "created_time": "2012-03-29T03:28:39+0000",
#        "name": "Geeky",
#        "id": "182527171867000"
#       }
#      ]
#     }
#    },
#    {
#     "id": "46205261"
#    },
#    {
#     "id": "46205330",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTM0MTMzNzc3OTk5",
#        "before": "MTM4OTQxNjgyODAzNTU4"
#       },
#       "next": "https://graph.facebook.com/46205330/likes?limit=10&access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&after=MTM0MTMzNzc3OTk5"
#      },
#      "data": [
#       {
#        "category": "Professional services",
#        "created_time": "2013-05-31T20:19:08+0000",
#        "name": "Callie Beale Photography",
#        "id": "138941682803558"
#       },
#       {
#        "category": "Shopping/retail",
#        "created_time": "2013-05-31T17:54:19+0000",
#        "name": "Sew Much Baggage",
#        "category_list": [
#         {
#          "id": "191647907538150",
#          "name": "Gift Shop"
#         }
#        ],
#        "id": "483207295023239"
#       },
#       {
#        "category": "Professional services",
#        "created_time": "2013-03-10T15:54:52+0000",
#        "name": "Finnegan Photography",
#        "id": "267040203338479"
#       },
#       {
#        "category": "Community organization",
#        "created_time": "2013-02-26T22:13:09+0000",
#        "name": "O'Donnell & Friends Open",
#        "id": "314499548652546"
#       },
#       {
#        "category": "Professional services",
#        "created_time": "2013-01-26T19:57:05+0000",
#        "name": "Hurst Photo",
#        "category_list": [
#         {
#          "id": "181475575221097",
#          "name": "Photographer"
#         }
#        ],
#        "id": "117080678385437"
#       },
#       {
#        "category": "Local business",
#        "created_time": "2012-04-02T20:03:04+0000",
#        "name": "BerryTree Photography",
#        "id": "72860335630"
#       },
#       {
#        "category": "Education",
#        "created_time": "2011-08-18T00:39:14+0000",
#        "name": "J H House Elementary School",
#        "id": "125723210857040"
#       },
#       {
#        "category": "Product/service",
#        "created_time": "2010-08-17T19:51:41+0000",
#        "name": "Defiant Photography",
#        "id": "45878494007"
#       },
#       {
#        "category": "Comedian",
#        "created_time": "2010-04-14T23:19:41+0000",
#        "name": "Etta May",
#        "id": "147395705294"
#       },
#       {
#        "category": "Local business",
#        "created_time": "2010-04-08T20:58:00+0000",
#        "name": "KT Lense Photography",
#        "category_list": [
#         {
#          "id": "2500",
#          "name": "Local Business"
#         }
#        ],
#        "id": "134133777999"
#       }
#      ]
#     }
#    },
#    {
#     "id": "500014243",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MjE4NzAwMjM1MDIx",
#        "before": "MTI5ODEyNjYwMzI2"
#       }
#      },
#      "data": [
#       {
#        "category": "Clothing",
#        "created_time": "2010-08-24T16:36:47+0000",
#        "name": "Tea Collection",
#        "id": "129812660326"
#       },
#       {
#        "category": "Public figure",
#        "created_time": "2009-12-08T23:15:25+0000",
#        "name": "Elinor Malendoski",
#        "category_list": [
#         {
#          "id": "1602",
#          "name": "Public Figure"
#         }
#        ],
#        "id": "218700235021"
#       }
#      ]
#     }
#    },
#    {
#     "id": "500019814"
#    },
#    {
#     "id": "500027746",
#     "likes": {
#      "paging": {
#       "cursors": {
#        "after": "MTE0MzEzNzY4NjA3ODc1",
#        "before": "NTEzMTA2NzcyNDI="
#       },
#       "next": "https://graph.facebook.com/500027746/likes?limit=10&access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&after=MTE0MzEzNzY4NjA3ODc1"
#      },
#      "data": [
#       {
#        "category": "Business services",
#        "created_time": "2013-10-01T13:43:33+0000",
#        "name": "Portent",
#        "category_list": [
#         {
#          "id": "170992992946914",
#          "name": "Marketing Consultant"
#         }
#        ],
#        "id": "51310677242"
#       },
#       {
#        "category": "Consulting/business services",
#        "created_time": "2013-10-01T06:08:25+0000",
#        "name": "Virante Online Marketing",
#        "category_list": [
#         {
#          "id": "170992992946914",
#          "name": "Marketing Consultant"
#         },
#         {
#          "id": "179672275401610",
#          "name": "Business Consultant"
#         },
#         {
#          "id": "164886566892249",
#          "name": "Advertising Agency"
#         }
#        ],
#        "id": "84478755498"
#       },
#       {
#        "category": "Company",
#        "created_time": "2013-09-16T04:10:35+0000",
#        "name": "Vogue Knitting Live",
#        "id": "131170876923780"
#       },
#       {
#        "category": "Community",
#        "created_time": "2013-09-04T12:36:43+0000",
#        "name": "The Penguin Anthology of 20th Century American Poetry edited by Rita Dove",
#        "id": "170993982969511"
#       },
#       {
#        "category": "Book",
#        "created_time": "2013-09-04T12:36:15+0000",
#        "name": "Plume, Penguin Group USA",
#        "id": "108154901515"
#       },
#       {
#        "category": "Publisher",
#        "created_time": "2013-09-04T12:36:13+0000",
#        "name": "Hudson Street Press, Penguin Group USA",
#        "id": "252673781871"
#       },
#       {
#        "category": "Non-profit organization",
#        "created_time": "2013-09-04T12:35:54+0000",
#        "name": "Annex Publishers",
#        "id": "1375092556049060"
#       },
#       {
#        "category": "Jewelry/watches",
#        "created_time": "2013-08-19T02:18:29+0000",
#        "name": "Judi Powers Jewelry",
#        "id": "363799750415778"
#       },
#       {
#        "category": "Company",
#        "created_time": "2013-08-15T15:16:56+0000",
#        "name": "Walters-Storyk Design Group (WSDG)",
#        "id": "68418963019"
#       },
#       {
#        "category": "Website",
#        "created_time": "2013-07-31T16:02:52+0000",
#        "name": "Digital Book World",
#        "id": "114313768607875"
#       }
#      ]
#     }
#    }
#   ]
#  },
#  "id": "630308116",
#  "name": "Ken Brooks"
# }

# %% [markdown]
# Note: If you attempt to run a query for all of your friends' likes and it appears to hang, it is probably because you have a lot of friends who have a lot of likes. If this happens, you may need to add limits and offsets to the fields in the query as described in Facebook's [field expansion](https://developers.facebook.com/docs/reference/api/field_expansion/) documentation. However, the <code>facebook</code> library that we'll use in the next example handles some of these issues, so it's recommended that you hold off and try it out first. This initial example is just to illustrate that Facebook's API is built on top of HTTP.
#
# A couple of field limit/offset examples that illustrate the possibilities follow:
#
# <code>
# fields = 'id,name,friends.limit(10).fields(likes)'            # Get all likes for 10 friends
# fields = 'id,name,friends.offset(10).limit(10).fields(likes)' # Get all likes for 10 more friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# </code>

# %% [markdown]
# ## Example 2. Querying the Graph API with Python

# %%
import facebook # pip install facebook-sdk
import json

# A helper function to pretty-print Python objects as JSON

def pp(o): 
    print json.dumps(o, indent=1)

# Create a connection to the Graph API with your access token

g = facebook.GraphAPI(ACCESS_TOKEN)

# Execute a few sample queries

print '---------------'
print 'Me'
print '---------------'
pp(g.get_object('me'))
print
print '---------------'
print 'My Friends'
print '---------------'
pp(g.get_connections('me', 'friends'))
print
print '---------------'
print 'Social Web'
print '---------------'
pp(g.request("search", {'q' : 'social web', 'type' : 'page'}))
# Out:
# ---------------
# Me
# ---------------
# {
#  "username": "ken.brooks",
#  "first_name": "Ken",
#  "last_name": "Brooks",
#  "verified": true,
#  "name": "Ken Brooks",
#  "locale": "en_US",
#  "gender": "male",
#  "updated_time": "2013-02-08T10:22:19+0000",
#  "link": "https://www.facebook.com/ken.brooks",
#  "timezone": -4,
#  "id": "630308116"
# }
# ---------------
# My Friends
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/630308116/friends?access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&limit=5000&offset=5000&__after_id=100004442322465"
#  },
#  "data": [
#   {
#    "name": "Matt Hong",
#    "id": "18834"
#   },
#   {
#    "name": "Carol Chiodo",
#    "id": "317552"
#   },
#   {
#    "name": "Iris Blasi",
#    "id": "1102512"
#   },
#   {
#    "name": "Megan Lamb",
#    "id": "4904172"
#   },
#   {
#    "name": "Joe Gallagher",
#    "id": "5615484"
#   },
#   {
#    "name": "Caitlin Stitt",
#    "id": "46205261"
#   },
#   {
#    "name": "Erin Hixson",
#    "id": "46205330"
#   },
#   {
#    "name": "Amanda Edmonds",
#    "id": "500014243"
#   },
#   {
#    "name": "Erin McElwain Wetzel",
#    "id": "500019814"
#   },
#   {
#    "name": "Peter McCarthy",
#    "id": "500027746"
#   },
#   {
#    "name": "Kathleen Doody Gallagher",
#    "id": "500039960"
#   },
#   {
#    "name": "James G. Robinson",
#    "id": "500047741"
#   },
#   {
#    "name": "Sacha Laustsen O'Flynn",
#    "id": "503526763"
#   },
#   {
#    "name": "Dan Silverburg",
#    "id": "506518888"
#   },
#   {
#    "name": "Kelley L. Allen",
#    "id": "510449794"
#   },
#   {
#    "name": "Asheesh Birla",
#    "id": "510603447"
#   },
#   {
#    "name": "Chelsea Vaughn Showalter",
#    "id": "515565367"
#   },
#   {
#    "name": "Jonathan Stowe",
#    "id": "515923399"
#   },
#   {
#    "name": "Kara Anne",
#    "id": "518485081"
#   },
#   {
#    "name": "Bob Diforio",
#    "id": "520405843"
#   },
#   {
#    "name": "Greg Bayer",
#    "id": "522917714"
#   },
#   {
#    "name": "Steve Potash",
#    "id": "525698967"
#   },
#   {
#    "name": "Mitchell Davis",
#    "id": "526662432"
#   },
#   {
#    "name": "Alex Albin",
#    "id": "528859102"
#   },
#   {
#    "name": "PJ Boardman",
#    "id": "534308554"
#   },
#   {
#    "name": "Alison Pendergast",
#    "id": "540526735"
#   },
#   {
#    "name": "Frank Lyman",
#    "id": "540771544"
#   },
#   {
#    "name": "Brian Napack",
#    "id": "541166365"
#   },
#   {
#    "name": "Fran Toolan",
#    "id": "550362377"
#   },
#   {
#    "name": "Laura Pople",
#    "id": "551158636"
#   },
#   {
#    "name": "Ritu Raj",
#    "id": "566985544"
#   },
#   {
#    "name": "Sonia Thind",
#    "id": "567738880"
#   },
#   {
#    "name": "Christopher Hyams Hart",
#    "id": "576713948"
#   },
#   {
#    "name": "Malle Vallik",
#    "id": "580280566"
#   },
#   {
#    "name": "Alberto Precht Rorris",
#    "id": "592001500"
#   },
#   {
#    "name": "Peggy Porter Mclaughlin",
#    "id": "592300916"
#   },
#   {
#    "name": "Gia Young",
#    "id": "595181315"
#   },
#   {
#    "name": "Siobhan Padgett",
#    "id": "595392276"
#   },
#   {
#    "name": "Pam Laycock",
#    "id": "603415099"
#   },
#   {
#    "name": "Tim Linerud",
#    "id": "603849940"
#   },
#   {
#    "name": "Peter Rogers",
#    "id": "607115344"
#   },
#   {
#    "name": "Suzi Cole",
#    "id": "607552532"
#   },
#   {
#    "name": "Myles C. Thompson",
#    "id": "608859504"
#   },
#   {
#    "name": "Theresa Horner",
#    "id": "614628384"
#   },
#   {
#    "name": "Rebecca Graveline Doane",
#    "id": "614670708"
#   },
#   {
#    "name": "Ed Solomon",
#    "id": "617562798"
#   },
#   {
#    "name": "Meg Fisher",
#    "id": "627286849"
#   },
#   {
#    "name": "Lee Fyock",
#    "id": "627887274"
#   },
#   {
#    "name": "Sol Rosenberg",
#    "id": "629085135"
#   },
#   {
#    "name": "Melissa Loder",
#    "id": "630239833"
#   },
#   {
#    "name": "Kenneth Brooks",
#    "id": "630710695"
#   },
#   {
#    "name": "Mark Ealden",
#    "id": "636757328"
#   },
#   {
#    "name": "Dreis Van Landuyt",
#    "id": "637679893"
#   },
#   {
#    "name": "Jeremy Ettinghausen",
#    "id": "638930177"
#   },
#   {
#    "name": "Heather Madsen",
#    "id": "642302677"
#   },
#   {
#    "name": "Jon Noring",
#    "id": "646935947"
#   },
#   {
#    "name": "Margaret McIntyre",
#    "id": "650993350"
#   },
#   {
#    "name": "Linh \u0110\u1ed7",
#    "id": "656363344"
#   },
#   {
#    "name": "Thierry Brethes",
#    "id": "662489491"
#   },
#   {
#    "name": "Mark Reichelt",
#    "id": "666677936"
#   },
#   {
#    "name": "Carolyn Pittis",
#    "id": "667428977"
#   },
#   {
#    "name": "Iris L. Hanney",
#    "id": "667946527"
#   },
#   {
#    "name": "Tracy Augustine",
#    "id": "673129215"
#   },
#   {
#    "name": "Joseph J. Esposito",
#    "id": "674759614"
#   },
#   {
#    "name": "Kari Paulson",
#    "id": "677143383"
#   },
#   {
#    "name": "Rob Reynolds",
#    "id": "678635952"
#   },
#   {
#    "name": "Ian Krantz",
#    "id": "684808407"
#   },
#   {
#    "name": "Marguerite Faraco Cardinal",
#    "id": "687997358"
#   },
#   {
#    "name": "Lara O'Loan",
#    "id": "688642331"
#   },
#   {
#    "name": "Stephen James Cole",
#    "id": "691948352"
#   },
#   {
#    "name": "Alicia Wise",
#    "id": "695884008"
#   },
#   {
#    "name": "Tom Miller",
#    "id": "699611809"
#   },
#   {
#    "name": "Philippa Lehar Sakos",
#    "id": "704512325"
#   },
#   {
#    "name": "Fionnuala Duggan",
#    "id": "705188311"
#   },
#   {
#    "name": "Ashley Gordon",
#    "id": "709777103"
#   },
#   {
#    "name": "Helen Mason",
#    "id": "710620898"
#   },
#   {
#    "name": "Ina Gottinger",
#    "id": "713525508"
#   },
#   {
#    "name": "Oliver Mac Cathmhaoil",
#    "id": "717095254"
#   },
#   {
#    "name": "Gwyn Headley",
#    "id": "717202343"
#   },
#   {
#    "name": "Peter Balis",
#    "id": "717612040"
#   },
#   {
#    "name": "John Ambrose",
#    "id": "720421149"
#   },
#   {
#    "name": "Keith Titan",
#    "id": "721998575"
#   },
#   {
#    "name": "Kate Tentler",
#    "id": "724840937"
#   },
#   {
#    "name": "Mark Bide",
#    "id": "724843905"
#   },
#   {
#    "name": "Christian Smythe",
#    "id": "729240617"
#   },
#   {
#    "name": "Jonathan Guttenberg",
#    "id": "731100933"
#   },
#   {
#    "name": "Mike Shatzkin",
#    "id": "733093288"
#   },
#   {
#    "name": "Jennifer Mitchell",
#    "id": "735068046"
#   },
#   {
#    "name": "Pandora Mather-Lees",
#    "id": "736193760"
#   },
#   {
#    "name": "Pat Waldo",
#    "id": "737830612"
#   },
#   {
#    "name": "David Wilk",
#    "id": "738809352"
#   },
#   {
#    "name": "Roger Sperberg",
#    "id": "739599427"
#   },
#   {
#    "name": "James Lichtenberg",
#    "id": "740829837"
#   },
#   {
#    "name": "Steve Kotrch",
#    "id": "742699127"
#   },
#   {
#    "name": "Dawn Santorella",
#    "id": "746827618"
#   },
#   {
#    "name": "Steve Sieck",
#    "id": "747121833"
#   },
#   {
#    "name": "Susan Kahelin Badger",
#    "id": "750958824"
#   },
#   {
#    "name": "Mike Violano",
#    "id": "751549287"
#   },
#   {
#    "name": "Andrew Willis",
#    "id": "757945345"
#   },
#   {
#    "name": "Band Cathy",
#    "id": "780702929"
#   },
#   {
#    "name": "J. Kirby Best",
#    "id": "789282401"
#   },
#   {
#    "name": "Adam Smith",
#    "id": "798535062"
#   },
#   {
#    "name": "Laura Nixon Dawson",
#    "id": "800574160"
#   },
#   {
#    "name": "Lindsay Stanley",
#    "id": "801287698"
#   },
#   {
#    "name": "Caroline Vanderlip",
#    "id": "823370593"
#   },
#   {
#    "name": "Andrew Grabois",
#    "id": "834850028"
#   },
#   {
#    "name": "Tom Grega",
#    "id": "848280540"
#   },
#   {
#    "name": "Lois Stitt",
#    "id": "853419880"
#   },
#   {
#    "name": "Claire Israel",
#    "id": "857515570"
#   },
#   {
#    "name": "Tomomi Melton",
#    "id": "1014844511"
#   },
#   {
#    "name": "Carol Moran",
#    "id": "1015245472"
#   },
#   {
#    "name": "Katrine Rosseland Johansen",
#    "id": "1031214882"
#   },
#   {
#    "name": "David Geppert",
#    "id": "1034536726"
#   },
#   {
#    "name": "Paulanne Queen",
#    "id": "1040255376"
#   },
#   {
#    "name": "Lorraine Shanley",
#    "id": "1067922154"
#   },
#   {
#    "name": "Neil Marquardt",
#    "id": "1072681516"
#   },
#   {
#    "name": "Sharra Lebov",
#    "id": "1079371538"
#   },
#   {
#    "name": "Karen Fetty",
#    "id": "1095175443"
#   },
#   {
#    "name": "Kristin Syvertson- Chase",
#    "id": "1097104683"
#   },
#   {
#    "name": "Kevin McKiernan",
#    "id": "1105608465"
#   },
#   {
#    "name": "Karen Fikri",
#    "id": "1129661444"
#   },
#   {
#    "name": "Andrea Kudzia",
#    "id": "1141517329"
#   },
#   {
#    "name": "Elyse Hornig Belanger",
#    "id": "1146097122"
#   },
#   {
#    "name": "Henry Topping",
#    "id": "1147210258"
#   },
#   {
#    "name": "Barry Gayheart",
#    "id": "1150317071"
#   },
#   {
#    "name": "Mimi McLaughlin",
#    "id": "1150704666"
#   },
#   {
#    "name": "William Gilbert",
#    "id": "1154257607"
#   },
#   {
#    "name": "Lorraine Carlson",
#    "id": "1157455939"
#   },
#   {
#    "name": "Dave Rauscher",
#    "id": "1162020959"
#   },
#   {
#    "name": "Jurgen Pauquet",
#    "id": "1171787007"
#   },
#   {
#    "name": "Peter Luzmore",
#    "id": "1174735925"
#   },
#   {
#    "name": "Margaret Witten",
#    "id": "1184101843"
#   },
#   {
#    "name": "Lisa Herling",
#    "id": "1185229932"
#   },
#   {
#    "name": "Robin Lucas",
#    "id": "1195592517"
#   },
#   {
#    "name": "Denay Wilding Knope",
#    "id": "1204570042"
#   },
#   {
#    "name": "Sanae Benoit",
#    "id": "1207077678"
#   },
#   {
#    "name": "John Warren",
#    "id": "1224855295"
#   },
#   {
#    "name": "Rob Berkley",
#    "id": "1230845632"
#   },
#   {
#    "name": "Terri Coats",
#    "id": "1247161837"
#   },
#   {
#    "name": "Marc Calvanico",
#    "id": "1251911613"
#   },
#   {
#    "name": "Jack Calhoun",
#    "id": "1269036345"
#   },
#   {
#    "name": "Becca Goldthwaite",
#    "id": "1281020000"
#   },
#   {
#    "name": "Lynn Butler",
#    "id": "1326280435"
#   },
#   {
#    "name": "Dennis Britton",
#    "id": "1347872107"
#   },
#   {
#    "name": "Roger S. Williams",
#    "id": "1353109298"
#   },
#   {
#    "name": "Matt Brooks",
#    "id": "1355677115"
#   },
#   {
#    "name": "Jake Rauscher",
#    "id": "1359301021"
#   },
#   {
#    "name": "Megan Brooks",
#    "id": "1360380278"
#   },
#   {
#    "name": "Larry Norton",
#    "id": "1365837034"
#   },
#   {
#    "name": "Judy Duffy",
#    "id": "1377525561"
#   },
#   {
#    "name": "Heidi Gladitsch Keeney",
#    "id": "1384689346"
#   },
#   {
#    "name": "Nichols Bleckley",
#    "id": "1394450840"
#   },
#   {
#    "name": "Joanne Alvord",
#    "id": "1422473234"
#   },
#   {
#    "name": "Cindy Pummer Rauscher",
#    "id": "1424918863"
#   },
#   {
#    "name": "Griffin Rauscher",
#    "id": "1429085818"
#   },
#   {
#    "name": "Kay Spencer",
#    "id": "1449722943"
#   },
#   {
#    "name": "Sharon Brown Furbee",
#    "id": "1452346024"
#   },
#   {
#    "name": "Harry L. Spencer",
#    "id": "1454732936"
#   },
#   {
#    "name": "Piero Chiodo",
#    "id": "1461813029"
#   },
#   {
#    "name": "Joy Mecca Arditti",
#    "id": "1474566365"
#   },
#   {
#    "name": "Tad Metzger",
#    "id": "1491063074"
#   },
#   {
#    "name": "Ann Marie Lamb",
#    "id": "1499808179"
#   },
#   {
#    "name": "Tracy Leone Ritter",
#    "id": "1514343229"
#   },
#   {
#    "name": "Stephen Fredette",
#    "id": "1518630155"
#   },
#   {
#    "name": "Adam Gaber",
#    "id": "1523346964"
#   },
#   {
#    "name": "David Taylor",
#    "id": "1538487557"
#   },
#   {
#    "name": "Ralph Zerbonia",
#    "id": "1543908367"
#   },
#   {
#    "name": "Elizabeth C Mackey",
#    "id": "1551372199"
#   },
#   {
#    "name": "Liz Koons Lynn",
#    "id": "1554776304"
#   },
#   {
#    "name": "Jennifer Wahi",
#    "id": "1557277312"
#   },
#   {
#    "name": "Melanie Roberts",
#    "id": "1575965696"
#   },
#   {
#    "name": "Bob Moschetto",
#    "id": "1616740486"
#   },
#   {
#    "name": "Maggie Wright",
#    "id": "1617850808"
#   },
#   {
#    "name": "Mark Arditti",
#    "id": "1625980902"
#   },
#   {
#    "name": "Lois Masini",
#    "id": "100000136682366"
#   },
#   {
#    "name": "Cory Juhl",
#    "id": "100000140820604"
#   },
#   {
#    "name": "Carrie Willicome",
#    "id": "100000190342090"
#   },
#   {
#    "name": "Konrad Hilbers",
#    "id": "100000221540435"
#   },
#   {
#    "name": "Matthew Stitt",
#    "id": "100000474471530"
#   },
#   {
#    "name": "Karen Birnie Garzon",
#    "id": "100000632280867"
#   },
#   {
#    "name": "Shah Karim",
#    "id": "100000718240606"
#   },
#   {
#    "name": "Mary Duffy Braun",
#    "id": "100000803886177"
#   },
#   {
#    "name": "Mabelle Montufar-Galarza",
#    "id": "100000955100957"
#   },
#   {
#    "name": "Kelly A. Quin",
#    "id": "100001242410332"
#   },
#   {
#    "name": "Mark Blair",
#    "id": "100002021071733"
#   },
#   {
#    "name": "Michelle Julet",
#    "id": "100002238552845"
#   },
#   {
#    "name": "Sheila Christine Savage",
#    "id": "100004442322465"
#   }
#  ]
# }
# ---------------
# Social Web
# ---------------
# {
#  "paging": {
#   "next": "https://graph.facebook.com/search?type=page&q=social+web&access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&limit=5000&offset=5000&__after_id=209873709053130"
#  },
#  "data": [
#   {
#    "category": "Professional services",
#    "name": "HyperArts Web Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "75033592467"
#   },
#   {
#    "category": "Local business",
#    "name": "Planit",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "108970815806976"
#   },
#   {
#    "category": "Professional services",
#    "name": "Codesky Web Design & Social Media",
#    "id": "278298328945358"
#   },
#   {
#    "category": "News/media website",
#    "name": "Web.Search.Social",
#    "id": "214631441934914"
#   },
#   {
#    "category": "Product/service",
#    "name": "Web of Knowledge",
#    "id": "119687984715358"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media Networks",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "151931054869702",
#      "name": "Document Service"
#     }
#    ],
#    "id": "266641420128830"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Profits",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "166707329019"
#   },
#   {
#    "category": "Product/service",
#    "name": "Packetmanxd - Web Design & Social Media",
#    "id": "585427021523043"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Rock Candy Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "106046343345"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SocialWebMarketing",
#    "id": "226633110719998"
#   },
#   {
#    "category": "Local business",
#    "name": "SocialMX Web | Marketing | Eventos",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "101466069892291"
#   },
#   {
#    "category": "Local business",
#    "name": "WebiMax",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "217960852867"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social & Web Marketing",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "172427156148334"
#   },
#   {
#    "category": "Professional services",
#    "name": "Horton Group",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "112724725464728"
#   },
#   {
#    "category": "Book",
#    "name": "Mining the Social Web",
#    "id": "146803958708175"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "SocialBo - Web Design and Social Media Online Presence For Small Businesses",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "475997555787520"
#   },
#   {
#    "category": "Company",
#    "name": "Enova4U Dise\u00f1o Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "218721764817225"
#   },
#   {
#    "category": "Professional services",
#    "name": "Balcom Agency",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "192021210817573",
#      "name": "Public Relations"
#     }
#    ],
#    "id": "169642990753"
#   },
#   {
#    "category": "Interest",
#    "name": "Internet marketing",
#    "id": "109356319084149"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Bee Web Marketing and Design",
#    "id": "187494864706626"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web in Fermento - Marketing nel Social Web e NewMedia Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "125310277520246"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "SocialWeb.ro",
#    "id": "185753574790507"
#   },
#   {
#    "category": "Local business",
#    "name": "etrade.ba | Social Media & Web",
#    "id": "217376194979375"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Life Social Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "147895125402338"
#   },
#   {
#    "category": "Business services",
#    "name": "SocialWebOPS",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "405979812779519"
#   },
#   {
#    "category": "School",
#    "name": "Social web - \u05e1\u05d5\u05e9\u05d9\u05d0\u05dc \u05d5\u05d5\u05d1",
#    "id": "419507011456285"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Innovation",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "140458819323627"
#   },
#   {
#    "category": "Local business",
#    "name": "Web1 Social Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "119307778101744"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Cafe",
#    "id": "255596497809113"
#   },
#   {
#    "category": "Product/service",
#    "name": "Webstring",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "533562380062950"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social WEB",
#    "id": "644404665577920"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Sherpas",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "105830116116453"
#   },
#   {
#    "category": "Business person",
#    "name": "Virtuallinda - Web Design & Social Media Training for the Busy Professional",
#    "id": "88492397926"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Blackstone",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "183720508337038"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web Day",
#    "id": "137161799695400"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "186573994697103",
#      "name": "Writing Service"
#     },
#     {
#      "id": "192021210817573",
#      "name": "Public Relations"
#     }
#    ],
#    "id": "144307838980365"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Visibly Connected - Web Design, Social Media Manager, & SEO",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "190805541029564"
#   },
#   {
#    "category": "Internet/software",
#    "name": "The Social Media Hat",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "403106733085954"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Nerd",
#    "id": "121955387828900"
#   },
#   {
#    "category": "Business services",
#    "name": "The Social J",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "167270964419"
#   },
#   {
#    "category": "Education website",
#    "name": "Social Web Learning",
#    "id": "149583259175"
#   },
#   {
#    "category": "Professional services",
#    "name": "Impulsive Labs Web Design & Social Media Management",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "261688960613759"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Web Army: Web Mobile Social Internet Marketing Services",
#    "id": "302648606541183"
#   },
#   {
#    "category": "Public figure",
#    "name": "The Social Media Web Genie",
#    "id": "537321239622767"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Social / Web Marketing Agency - Stir USA | Canada",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "152246029758"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Social",
#    "id": "481173118576926"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Marketing Experts",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "137149422976563"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "SEO Workers - Forensic SEO & Social Semantic Web Consulting",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "22362057425"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Web Ranking",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "470852336273104"
#   },
#   {
#    "category": "Local business",
#    "name": "Daddy Design",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "34572893685"
#   },
#   {
#    "category": "Local business",
#    "name": "WebSocialTraffic",
#    "id": "19939664284"
#   },
#   {
#    "category": "Professional services",
#    "name": "RedHot Design | Web Designers + Social Media Strategists",
#    "category_list": [
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "100306133360993"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Web Traffic & Social Networking",
#    "id": "159898507447542"
#   },
#   {
#    "category": "Tv channel",
#    "name": "WEB TV Social Network - GR Comunicazione",
#    "id": "581952661860081"
#   },
#   {
#    "category": "Small business",
#    "name": "Social Web Tactics",
#    "category_list": [
#     {
#      "id": "2237",
#      "name": "Small Business"
#     }
#    ],
#    "id": "162973743866087"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Magazine",
#    "id": "202163419911377"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Jat Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "109660825787903"
#   },
#   {
#    "category": "Website",
#    "name": "Social Web BREAKFAST",
#    "id": "175318852545291"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social-Work Web",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "243859642426303"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Webfluence Social Media & Internet Marketing",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "112879788755706"
#   },
#   {
#    "category": "Non-profit organization",
#    "name": "Second Wednesday - Web industry social events",
#    "id": "83659087689"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Media Monster",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "191783864204943"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Alliance",
#    "id": "160477007390933"
#   },
#   {
#    "category": "Local business",
#    "name": "My Social Marketing Network - Social Media Consulting",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "145718952145119"
#   },
#   {
#    "category": "Business/economy website",
#    "name": "G&B Marketing | Web & Social Media",
#    "category_list": [
#     {
#      "id": "2702",
#      "name": "Business/Economy Website"
#     }
#    ],
#    "id": "331604230252618"
#   },
#   {
#    "category": "Small business",
#    "name": "Mystified By Social Media - Web Design, Graphics, Magazine & More",
#    "id": "190698234331659"
#   },
#   {
#    "category": "Education",
#    "name": "The Social Mobile WEB Business Conference",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "290193207726357"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "103944626326539"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Grafdom - Web Design & Social Media",
#    "id": "190124415513"
#   },
#   {
#    "category": "Author",
#    "name": "Max Weber",
#    "id": "107925445896860"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Ask.Geeks",
#    "category_list": [
#     {
#      "id": "139823692748565",
#      "name": "Computers & Electronics"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "215343825145859",
#      "name": "Social Club"
#     }
#    ],
#    "id": "398619216870328"
#   },
#   {
#    "category": "Business services",
#    "name": "PresentationMultimedia - Social Media, SEO, DVD & Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "173932019310961"
#   },
#   {
#    "category": "Internet/software",
#    "name": "ICTIP - Online Marketing, Social Media Management and Web Development",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "147188657823"
#   },
#   {
#    "category": "Product/service",
#    "name": "On The Webb Social Media Services",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "210125749066257"
#   },
#   {
#    "category": "Company",
#    "name": "Weber Shandwick Social Impact",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "89444069963"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Kreativevue Web Design & Social Media",
#    "id": "426710170752907"
#   },
#   {
#    "category": "Business services",
#    "name": "Martin Reynolds - Web & Social Media Consultant",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "167547383402193"
#   },
#   {
#    "category": "Personal website",
#    "name": "THE JAGUAR SOCIAL NETWORK  WEBSITE",
#    "id": "114852928532072"
#   },
#   {
#    "category": "Company",
#    "name": "WebCreationUK",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "195219031724"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Leading Logic - Web, Social, Marketing, Design",
#    "id": "136481676384923"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Social Web Tools",
#    "id": "36314080679"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web2social",
#    "id": "127415450642739"
#   },
#   {
#    "category": "Business services",
#    "name": "socialWEB",
#    "id": "114355558650055"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Douro at Social Media Networking",
#    "id": "454451468008331"
#   },
#   {
#    "category": "School",
#    "name": "Web Marketing School",
#    "id": "696599063702813"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebSocial",
#    "id": "208290102524008"
#   },
#   {
#    "category": "Local business",
#    "name": "Quisk Design - Websites, Branding & Social Media",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "328671177050"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Pi\u00f9 - Social Media Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "264261473614294"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebShark360",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "356446751108327"
#   },
#   {
#    "category": "Product/service",
#    "name": "Allographics Web & Social Media Design Solutions",
#    "id": "181729338411"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Web Associates",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ],
#    "id": "327997047315600"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Media Web Development",
#    "id": "125248858533"
#   },
#   {
#    "category": "Local business",
#    "name": "Micro Sites, Web Design, Social Media, SEO, SEM, Logo's, Database.",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "64623240754"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "My Social Web",
#    "category_list": [
#     {
#      "id": "186573994697103",
#      "name": "Writing Service"
#     }
#    ],
#    "id": "76277666156"
#   },
#   {
#    "category": "Website",
#    "name": "PickMe Web - Online Social Bookmarking",
#    "id": "116207408393755"
#   },
#   {
#    "category": "Community",
#    "name": "Marci Rosenblum - Expert SEO Specialist, Web Traffic, Social Media Marketer",
#    "id": "70863093045"
#   },
#   {
#    "category": "Local business",
#    "name": "Dot Ingenuity Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "131570646875176"
#   },
#   {
#    "category": "Local business",
#    "name": "MerlinFX Web Email Marketing Social Media",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "139004380018"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebSocial Business Solutions",
#    "id": "444124702299250"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "iSocialWeb",
#    "id": "462294513847158"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "MasseyMedia, Inc. - Web Design and Social Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "105451942867889"
#   },
#   {
#    "category": "Community",
#    "name": "Social Web",
#    "id": "156184496617"
#   },
#   {
#    "category": "Interest",
#    "name": "Social web",
#    "id": "112879218725926"
#   },
#   {
#    "category": "Community",
#    "name": "Webster Alumni Social Group",
#    "id": "487171701376262"
#   },
#   {
#    "category": "Professional services",
#    "name": "Social Web Quick Start",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "186129094876663"
#   },
#   {
#    "category": "App page",
#    "name": "Defensio Social Web Security",
#    "id": "243130985760964"
#   },
#   {
#    "category": "Website",
#    "name": "SocialWebLike",
#    "id": "101946616632016"
#   },
#   {
#    "category": "Concert venue",
#    "name": "SocialWeb",
#    "id": "186493478082456"
#   },
#   {
#    "category": "Company",
#    "name": "More Cabbage Social PR, Branding, & Websites",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     }
#    ],
#    "id": "216734806323"
#   },
#   {
#    "category": "Internet/software",
#    "name": "webSocial",
#    "id": "224315387674634"
#   },
#   {
#    "category": "Local business",
#    "name": "Web Social",
#    "id": "330618789326"
#   },
#   {
#    "category": "Local business",
#    "name": "WebSouls",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "201580029921649"
#   },
#   {
#    "category": "Local business",
#    "name": "WEB2NULL.at - Social Media WebDesign Agentur",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ],
#    "id": "107423162613389"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Erudite Web Solutions",
#    "category_list": [
#     {
#      "id": "198503866828628",
#      "name": "Organization"
#     }
#    ],
#    "id": "534647476574962"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Wild West Online Productions - Social Media & Web Video Consultants",
#    "id": "122255047839285"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Blenn-Solutions - Social Media Know-How",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     }
#    ],
#    "id": "121845631203388"
#   },
#   {
#    "category": "Company",
#    "name": "Sweden Social Web Camp",
#    "id": "290284817827"
#   },
#   {
#    "category": "Business services",
#    "name": "Web Search Now",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "130417073799400"
#   },
#   {
#    "category": "Website",
#    "name": "Mike Mueller: Marketing, Web Design, & Social Media Consultation",
#    "id": "50818804012"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Academy",
#    "id": "192046090848741"
#   },
#   {
#    "category": "Company",
#    "name": "Digital Domain - Website & Social Media Specialists",
#    "id": "357741767651125"
#   },
#   {
#    "category": "Local business",
#    "name": "Symphoni",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "192021210817573",
#      "name": "Public Relations"
#     }
#    ],
#    "id": "264813256962034"
#   },
#   {
#    "category": "Website",
#    "name": "WebCamSocial.com",
#    "id": "193570570659564"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Development Trends",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "156420394543268"
#   },
#   {
#    "category": "Company",
#    "name": "WebGap Ltd",
#    "id": "277161695712033"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Promotions",
#    "id": "234335963269949"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Strategies",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ],
#    "id": "8387137434"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Meta Social Web",
#    "id": "117185225027930"
#   },
#   {
#    "category": "Business services",
#    "name": "bSocial",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "365191623584856"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Chaser Media - Social Media, Web Design and Photography Services",
#    "id": "195822857133037"
#   },
#   {
#    "category": "Musical instrument",
#    "name": "Wesome Web & Social Media solutions",
#    "id": "461405120593275"
#   },
#   {
#    "category": "Professional services",
#    "name": "webfeuer - Social Media und mehr!",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "369613539636"
#   },
#   {
#    "category": "Product/service",
#    "name": "Social Web Week Connecticut",
#    "id": "128455980522180"
#   },
#   {
#    "category": "Company",
#    "name": "Social WEBZ",
#    "id": "412582482097898"
#   },
#   {
#    "category": "Education",
#    "name": "ITE College West - Nitec in Social Media and Web Development",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "162257397196866"
#   },
#   {
#    "category": "Website",
#    "name": "ABDLmatch.com - Your ABDL Dating & Social Network Website",
#    "id": "156913127790511"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Social Web Tools",
#    "id": "403059893050740"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Prolong Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "178669642178193",
#      "name": "Social Services"
#     }
#    ],
#    "id": "147657805394837"
#   },
#   {
#    "category": "Education",
#    "name": "Social Media Marketing & Web Communication - Executive Master SDC IULM",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "104917969542058"
#   },
#   {
#    "category": "Company",
#    "name": "Hi Fi Social Web",
#    "id": "196298563744277"
#   },
#   {
#    "category": "Business services",
#    "name": "Drive Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "155873241210106"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "WebCobblers",
#    "id": "420008741374114"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Fortress Social Branding",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "169056916473899",
#      "name": "Broadcasting & Media Production"
#     }
#    ],
#    "id": "191385074698"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "ForchuTeck Consulting - Web Designers, Technology Support, Social Media",
#    "category_list": [
#     {
#      "id": "2255",
#      "name": "Computers/Technology"
#     }
#    ],
#    "id": "148165253093"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Advertising Enterprises (Web Design, Social Media, SEO &  Marketing)",
#    "id": "6049597557"
#   },
#   {
#    "category": "Professional services",
#    "name": "Web Design & SEO EU",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "622102474472151"
#   },
#   {
#    "category": "Professional services",
#    "name": "Web Monster Inc",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "166991166731917"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "iptaque, web social, formation",
#    "id": "241894749184616"
#   },
#   {
#    "category": "Local business",
#    "name": "Logic Web Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "358483060859947",
#      "name": "Startup"
#     }
#    ],
#    "id": "180645498671651"
#   },
#   {
#    "category": "Local business",
#    "name": "The Green Internet Group",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "69370629970"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Speak Social",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "127692573953699"
#   },
#   {
#    "category": "Website",
#    "name": "SeashoreWeb Social Media Marketing",
#    "id": "106838049410541"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Rory Martin Seattle Web Design and Social Media",
#    "id": "198472820260168"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Drive Digital Group",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "210070935740062"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "DS | Web Marketing y Redes Sociales",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "127508757393163"
#   },
#   {
#    "category": "Local business",
#    "name": "BBN 411",
#    "category_list": [
#     {
#      "id": "186982054657561",
#      "name": "Sports & Recreation"
#     },
#     {
#      "id": "354275401259620",
#      "name": "Nightlife"
#     },
#     {
#      "id": "215343825145859",
#      "name": "Social Club"
#     }
#    ],
#    "id": "153628154663279"
#   },
#   {
#    "category": "Local business",
#    "name": "Webhead Interactive",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     }
#    ],
#    "id": "32154077543"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Cardinal Web Solutions",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "96832772061"
#   },
#   {
#    "category": "Company",
#    "name": "YouLikeFans - Social Media Website Tool & Community",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ],
#    "id": "436356429737029"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web Media Kings",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "128177227345458"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Digital For Dummies | Social, Web & other Technical Stuff",
#    "id": "476313985731653"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "WebRev Marketing & Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "174521407814"
#   },
#   {
#    "category": "Internet/software",
#    "name": "7Blaze - True Social Experience",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "215297361818239"
#   },
#   {
#    "category": "Personal website",
#    "name": "Web Social",
#    "id": "146017952079740"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "Real-time Social Web",
#    "id": "121363354543881"
#   },
#   {
#    "category": "Professional services",
#    "name": "Avalde Digital - Web Mobile Social Agency",
# ...
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "544959402209009"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Mouthful Social Media",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "150484138319914"
#   },
#   {
#    "category": "Local business",
#    "name": "EasyWebFix.com ( Web Design, E-Marketing, Social Networking)",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "157348074281885"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Game Universe",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "50117529985"
#   },
#   {
#    "category": "Local business",
#    "name": "Web-Consult.ro",
#    "category_list": [
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ],
#    "id": "560514617337777"
#   },
#   {
#    "category": "Book",
#    "name": "Informe APEI sobre Web Social",
#    "id": "33274669157"
#   },
#   {
#    "category": "Business services",
#    "name": "Imagination Marketing - SEO Website Marketing Social Media Management",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "453192678092536"
#   },
#   {
#    "category": "Education",
#    "name": "The Social Mobile Web Business Conference London",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "410179745689608"
#   },
#   {
#    "category": "Local business",
#    "name": "TTLP Social Media Services",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "103592169772110"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Webpointsolution",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "373677282715471"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Susan Critelli - Making Business More Personal",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "82791504262"
#   },
#   {
#    "category": "Website",
#    "name": "vGal Website Content Writing, Social Media & Solutions",
#    "id": "120224928014658"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "KEMEmedia",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "215077818634666"
#   },
#   {
#    "category": "Company",
#    "name": "Social Media Ninjas | Santa Rosa Internet Marketing Consultants",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "152123711502236"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Web Consulting Test Page",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "159918207405302"
#   },
#   {
#    "category": "Local business",
#    "name": "Leslie Trosset-Social Media-SEO-Expert-Web Design-Albany NY",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "54677574397"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media Webdesign",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "129477563809733"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media Marketing Boston",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     }
#    ],
#    "id": "527953287231936"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Brothers- Web Solutions",
#    "id": "583083878419053"
#   },
#   {
#    "category": "Business services",
#    "name": "Crate78",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "1385582108340936"
#   },
#   {
#    "category": "Internet/software",
#    "name": "OvenPOP 360: A Social Media Agency",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "163919803682145"
#   },
#   {
#    "category": "Company",
#    "name": "Donkrea Agencia Dise\u00f1o Web y Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "616960891669526"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Elios Interactive: Social Media e Web Marketing Agency",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "162255837181162"
#   },
#   {
#    "category": "Non-governmental organization (ngo)",
#    "name": "MPE",
#    "category_list": [
#     {
#      "id": "178669642178193",
#      "name": "Social Services"
#     },
#     {
#      "id": "215343825145859",
#      "name": "Social Club"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "559917084067723"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Webrunner Media Group",
#    "id": "203262656375164"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Federation",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "433340806773778"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Local Web Innovations",
#    "id": "332927290101028"
#   },
#   {
#    "category": "Media/news/publishing",
#    "name": "Browse Me / Web Design & Development",
#    "id": "152517474893170"
#   },
#   {
#    "category": "Professional services",
#    "name": "Computer Web Social Media of Shelby",
#    "category_list": [
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "207112126105577"
#   },
#   {
#    "category": "Business services",
#    "name": "Peachtree Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "177352788975034",
#      "name": "Online Advertising Service"
#     }
#    ],
#    "id": "172697839438409"
#   },
#   {
#    "category": "Local business",
#    "name": "Cube Web Solutions",
#    "id": "195784593801209"
#   },
#   {
#    "category": "Business services",
#    "name": "The Social Wall",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "199653680098985"
#   },
#   {
#    "category": "Professional services",
#    "name": "Sitio Web Social",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "178613775521718"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Alive Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "601048219913365"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SocialCee Africa",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "590345617688185"
#   },
#   {
#    "category": "Local business",
#    "name": "Social Media Easy",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "323530920524"
#   },
#   {
#    "category": "Business services",
#    "name": "Allen Social Media",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ],
#    "id": "333655826745662"
#   },
#   {
#    "category": "Professional services",
#    "name": "Binding Digital Ltd",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "262192350559430"
#   },
#   {
#    "category": "Professional services",
#    "name": "Sun Social SEO",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "226277557526409"
#   },
#   {
#    "category": "Club",
#    "name": "My Asansol City",
#    "category_list": [
#     {
#      "id": "215343825145859",
#      "name": "Social Club"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "296862927058877",
#      "name": "Community Center"
#     }
#    ],
#    "id": "1400497696832847"
#   },
#   {
#    "category": "Education",
#    "name": "The Social Mobile Web Business Conference Bristol",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ],
#    "id": "201096466573296"
#   },
#   {
#    "category": "Business services",
#    "name": "Website Social Media Development",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "522531034450480"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Antonio Ferreira's Websites and Social Media",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "477744705618931"
#   },
#   {
#    "category": "Business services",
#    "name": "Zearchez",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ],
#    "id": "571677952875234"
#   },
#   {
#    "category": "Local business",
#    "name": "Adtech Web Solutions -  Social Media Consultants",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "149251555126795"
#   },
#   {
#    "category": "Local business",
#    "name": "Sapphire Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "468911869848250"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Visual Matter Social Media Specialist San Jose",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "423217034426019"
#   },
#   {
#    "category": "Professional services",
#    "name": "J\u00f6rgensen - Verm\u00f6nt Social Media Marketing and Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ],
#    "id": "423150274414013"
#   },
#   {
#    "category": "Professional services",
#    "name": "Limitless Social Media Management & Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ],
#    "id": "358076844231190"
#   },
#   {
#    "category": "Business services",
#    "name": "Social Media App Design - Brand Web Direct",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ],
#    "id": "180204945400699"
#   },
#   {
#    "category": "Business services",
#    "name": "Defede media social marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ],
#    "id": "377228235700809"
#   },
#   {
#    "category": "Internet/software",
#    "name": "Web-Marketing Sociale",
#    "id": "395618487194800"
#   },
#   {
#    "category": "Computers/internet website",
#    "name": "W3T Web Portal",
#    "id": "143754265718102"
#   },
#   {
#    "category": "Internet/software",
#    "name": "WOOI web agency | comunicazione, social marketing, new media.",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ],
#    "id": "157323880954162"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Local Optimism : SEO + Web Design",
#    "id": "117673741640657"
#   },
#   {
#    "category": "Computers/technology",
#    "name": "Website Wellness - Web, SEO & Social Marketing",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ],
#    "id": "173869832661277"
#   },
#   {
#    "category": "Internet/software",
#    "name": "SEOLaws.com - SEO . PPC . Social Media . Web Design . Video . NonProfits",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ],
#    "id": "185123218198865"
#   },
#   {
#    "category": "Professional services",
#    "name": "SM Social Marketing",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ],
#    "id": "572970539420162"
#   },
#   {
#    "category": "Consulting/business services",
#    "name": "Social Media 360 - Your Virtual Social Media Agency",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ],
#    "id": "209873709053130"
#   }
#  ]
# }

# %% [markdown]
# ## Example 3. Results for a Graph API query for Mining the Social Web

# %%
# Get an instance of Mining the Social Web
# Using the page name also works if you know it.
# e.g. 'MiningTheSocialWeb' or 'CrossFit'
mtsw_id = '146803958708175'
pp(g.get_object(mtsw_id))
# Out:
# {
#  "category": "Book",
#  "username": "MiningTheSocialWeb",
#  "about": "Analyzing Data from Facebook, Twitter, LinkedIn, and Other Social Media Sites. Twitter: @SocialWebMining",
#  "talking_about_count": 61,
#  "description": "Facebook, Twitter, LinkedIn, Google+, and other social web properties generate a wealth of valuable social data, but how can you tap into this data and discover who\u2019s connecting with whom, which insights are lurking just beneath the surface, and what people are talking about? This book shows you how to answer these questions and many more. Each chapter combines popular and useful social web data with analysis techniques and visualization to help you find the needles in the social haystack that you've been looking for\u2014as well as many you probably didn't even know existed.\n\nIn this expanded and thoroughly revised second edition you\u2019ll learn how to:\n\n* Navigate the most popular social web APIs to access, collect, analyze, and visualize social web data\n* Employ IPython Notebook and other easy to use Python packages such as the Natural Language Toolkit, NetworkX, and Matplotlib to efficiently sift through social web data as part of an experimentally-driven approach to discovering insights in social web data\n* Apply advanced text-mining techniques such as TF-IDF, cosine similarity, collocation analysis, document summarization, and clique detection to human language data that you'll encounter all over the web\n* Bootstrap interest graphs by discovering latent affinities between people, programming languages, and coding projects from GitHub data\n* Visualize social web data with D3, a state-of-the-art HTML5 and JavaScript toolkit\n\nThe book's source code is maintained in a GitHub repository maintained by the author and can be deployed as turn-key virtual machine with each chapter's source code presented in an interactive and easy to use IPython Notebook format. No complex third-party installations or advanced Python knowledge is required to get the most out of this book.",
#  "company_overview": "Like It here on Facebook!\n\nFollow @SocialWebMining on Twitter: http://twitter.com/SocialWebMining\n\nGet the source code for the revised and expanded second edition on GitHub: http://bit.ly/MiningTheSocialWeb2E\n\nGet the (now legacy) source code for the first edition on GitHub: http://bit.ly/SocialWebMining",
#  "release_date": "January 2011",
#  "can_post": true,
#  "cover": {
#   "source": "https://scontent-a.xx.fbcdn.net/hphotos-ash3/s720x720/1003733_522831997772034_741301400_n.jpg",
#   "cover_id": 522831997772034,
#   "offset_x": 0,
#   "offset_y": 56
#  },
#  "mission": "Teaches you how to navigate the most popular social web APIs to access, collect, analyze, and visualize social web data with IPython Notebook and other easy to use Python packages and visualization tools.",
#  "name": "Mining the Social Web",
#  "founded": "January 2011",
#  "website": "http://miningthesocialweb.com",
#  "awards": "Jolt Productivity Award (1st Ed.) -  http://drdobbs.com/joltawards/231500080?pgno=6",
#  "likes": 1236,
#  "were_here_count": 0,
#  "genre": "Data Mining",
#  "link": "https://www.facebook.com/MiningTheSocialWeb",
#  "general_info": "Analyzing Data from Facebook, Twitter, LinkedIn, and Other Social Media Sites - Get it at http://bit.ly/135dHfs",
#  "id": "146803958708175",
#  "is_published": true
# }

# %% [markdown]
# ## Example 4. Querying the Graph API for Open Graph objects by their URLs

# %%
# MTSW catalog link
pp(g.get_object('http://shop.oreilly.com/product/0636920030195.do'))

# PCI catalog link
pp(g.get_object('http://shop.oreilly.com/product/9780596529321.do'))
# Out:
# {
#  "id": "http://shop.oreilly.com/product/0636920030195.do",
#  "shares": 162
# }
# {
#  "category": "Book",
#  "about": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "can_post": true,
#  "description": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "talking_about_count": 0,
#  "name": "Programming Collective Intelligence",
#  "link": "http://shop.oreilly.com/product/9780596529321.do",
#  "likes": 18,
#  "were_here_count": 0,
#  "id": "221689464577245",
#  "is_published": true
# }

# %% [markdown]
# ## Example 5. Comparing likes between Coke and Pepsi fan pages

# %%
# Find Pepsi and Coke in search results

pp(g.request('search', {'q' : 'pepsi', 'type' : 'page', 'limit' : 5}))
pp(g.request('search', {'q' : 'coke', 'type' : 'page', 'limit' : 5}))

# Use the ids to query for likes

pepsi_id = '56381779049' # Could also use 'PepsiUS'
coke_id = '40796308305'  # Could also use 'CocaCola'

# A quick way to format integers with commas every 3 digits
def int_format(n): return "{:,}".format(n)

print "Pepsi likes:", int_format(g.get_object(pepsi_id)['likes'])
print "Coke likes:", int_format(g.get_object(coke_id)['likes'])
# Out:
# {
#  "paging": {
#   "next": "https://graph.facebook.com/search?limit=5&type=page&q=pepsi&access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&offset=5&__after_id=157659814298427"
#  },
#  "data": [
#   {
#    "category": "Food/beverages",
#    "name": "PepsiCo",
#    "category_list": [
#     {
#      "id": "200019523363001",
#      "name": "Food & Beverage Service & Distribution"
#     }
#    ],
#    "id": "260431051694"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi",
#    "id": "107173405982788"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi Max",
#    "id": "10098929349"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Pepsi Philippines",
#    "id": "400886490082"
#   },
#   {
#    "category": "Sports venue",
#    "name": "Pepsi Arena",
#    "category_list": [
#     {
#      "id": "109976259083543",
#      "name": "Sports Venue & Stadium"
#     },
#     {
#      "id": "273819889375819",
#      "name": "Restaurant"
#     },
#     {
#      "id": "197817313562497",
#      "name": "Museum"
#     }
#    ],
#    "id": "157659814298427"
#   }
#  ]
# }
# {
#  "paging": {
#   "next": "https://graph.facebook.com/search?limit=5&type=page&q=coke&access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&offset=5&__after_id=343815695662228"
#  },
#  "data": [
#   {
#    "category": "Food/beverages",
#    "name": "Coca-Cola",
#    "id": "40796308305"
#   },
#   {
#    "category": "Tv show",
#    "name": "Coke Studio",
#    "category_list": [
#     {
#      "id": "133436743388217",
#      "name": "Arts & Entertainment"
#     }
#    ],
#    "id": "16944632531"
#   },
#   {
#    "category": "Food",
#    "name": "Chocolate",
#    "id": "113472061996206"
#   },
#   {
#    "category": "Tv show",
#    "name": "Coke Studio at MTV",
#    "id": "127266094017030"
#   },
#   {
#    "category": "Food/beverages",
#    "name": "Coke Studio \u0628\u0627\u0644\u0639\u0631\u0628\u064a",
#    "id": "343815695662228"
#   }
#  ]
# }
# Pepsi likes:
# 25,075,334
# Coke likes:
# 74,746,451

# %% [markdown]
# ## Example 6. Querying a page for its "feed" and "links" connections

# %%
pp(g.get_connections(pepsi_id, 'feed'))
pp(g.get_connections(pepsi_id, 'links'))

pp(g.get_connections(coke_id, 'feed'))
pp(g.get_connections(coke_id, 'links'))
# Out:
# {
#  "paging": {
#   "next": "https://graph.facebook.com/56381779049/feed?access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&limit=25&until=1382890555",
#   "previous": "https://graph.facebook.com/56381779049/feed?access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&limit=25&since=1382987042&__previous=1"
#  },
#  "data": [
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-ash3/q71/s480x480/1383721_561397603932207_1337383881_n.jpg",
#    "from": {
#     "name": "Chad Wayne Wilson",
#     "id": "100001859183750"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/561397603932207",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/561397603932207",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T19:04:02+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=561397603932207&set=o.56381779049&type=1",
#    "object_id": "561397603932207",
#    "created_time": "2013-10-28T19:04:02+0000",
#    "message": "PLEASE READ AND TELL PEPSI JUST WHAT YOU THINK ABOUT THIS!!!!!!!!!!!!!!",
#    "type": "photo",
#    "id": "56381779049_561397603932207",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "name": "Phil Stagnaro",
#     "id": "100005986960836"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152087386034050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152087386034050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T17:32:07+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "NTYzODE3NzkwNDk=",
#       "before": "NTYzODE3NzkwNDk="
#      }
#     },
#     "data": [
#      {
#       "id": "56381779049",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T17:32:07+0000",
#    "message": "Forever Pepsi",
#    "type": "status",
#    "id": "56381779049_10152087386034050"
#   },
#   {
#    "picture": "https://fbcdn-photos-g-a.akamaihd.net/hphotos-ak-prn1/544105_10152087207029050_675509190_s.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDA1MjI5NTExMjIz",
#       "before": "MTAwMDAwNTM3ODU5MTY2"
#      },
#      "next": "https://graph.facebook.com/56381779049_10152087323699050/likes?access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&limit=25&after=MTAwMDA1MjI5NTExMjIz"
#     },
#     "data": [
#      {
#       "id": "100000537859166",
#       "name": "Lupe Lopez"
#      },
#      {
#       "id": "100001361492942",
#       "name": "Ricky Chapa"
#      },
#      {
#       "id": "100000581157846",
#       "name": "Jenny Spies-Falls"
#      },
#      {
#       "id": "100002984104992",
#       "name": "Brian Ecker"
#      },
#      {
#       "id": "100003488306003",
#       "name": "Robert Coaxum"
#      },
#      {
#       "id": "100000659972785",
#       "name": "Mick Vazquez"
#      },
#      {
#       "id": "740528400",
#       "name": "Bilkis Mita Escalante"
#      },
#      {
#       "id": "100001052758341",
#       "name": "Donald Franklin"
#      },
#      {
#       "id": "100004579601659",
#       "name": "Brenda Saunders"
#      },
#      {
#       "id": "100004587362117",
#       "name": "Jeanette White"
#      },
#      {
#       "id": "100002196484098",
#       "name": "Carlos Maye"
#      },
#      {
#       "id": "1548132753",
#       "name": "Kathy Gordillo"
#      },
#      {
#       "id": "100002767473618",
#       "name": "Marisol Escalante Lyda"
#      },
#      {
#       "id": "100001671748847",
#       "name": "Eduardo Ortiz"
#      },
#      {
#       "id": "100000881214811",
#       "name": "Felix Silva Jr."
#      },
#      {
#       "id": "100000208291329",
#       "name": "Arun Chopra"
#      },
#      {
#       "id": "100000122432907",
#       "name": "Patty Leeson-Nasser"
#      },
#      {
#       "id": "100003699669931",
#       "name": "Israel Yolanda Alvarado"
#      },
#      {
#       "id": "100001847060689",
#       "name": "Mishele Matlock"
#      },
#      {
#       "id": "100003845003848",
#       "name": "Ruth Sena"
#      },
#      {
#       "id": "1647952444",
#       "name": "Mary Cordray"
#      },
#      {
#       "id": "100001532453071",
#       "name": "Markle Leanne Prindle"
#      },
#      {
#       "id": "1572550140",
#       "name": "Alfred Golightly"
#      },
#      {
#       "id": "100000674897180",
#       "name": "Shawna Lucas"
#      },
#      {
#       "id": "100005229511223",
#       "name": "Adan Chavez Jr."
#      }
#     ]
#    },
#    "from": {
#     "category": "Food/beverages",
#     "name": "Pepsi",
#     "id": "56381779049"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "NQ==",
#       "before": "Mjk="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Jane Anne",
#        "id": "100000646981468"
#       },
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:01:01+0000",
#       "message": "Pepsi and pizza is the best!!",
#       "id": "10152087207029050_12499888",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Laura Reese O'Connell",
#        "id": "573610963"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-10-28T18:56:45+0000",
#       "message": "one of my favorite combos!",
#       "id": "10152087207029050_12500832",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Cynthia Vandergrift",
#        "id": "100000138520924"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:21:43+0000",
#       "message": "This is so much bull crap you send a message to my email then don't let me use the email unless I upgrade.  I can't upgrade because it messes with my work files. smh don't advertise something that is not true!",
#       "id": "10152087207029050_12500038",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Lillian Martha Compo",
#        "id": "100002683292200"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T18:11:01+0000",
#       "message": "maybe just the PEPSI!!!!",
#       "id": "10152087207029050_12500480",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Judy Caradori",
#        "id": "100001135004930"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:49:21+0000",
#       "message": "No thank you.He cut employee hours so not to pay health care.",
#       "id": "10152087207029050_12500314",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Amy Lamm",
#        "id": "100001412082711"
#       },
#       "message_tags": [
#        {
#         "length": 10,
#         "offset": 0,
#         "type": "user",
#         "id": "1369381080",
#         "name": "Leann Lamm"
#        }
#       ],
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:36:47+0000",
#       "message": "Leann Lamm loves Pepsi, pizza, and cucumbers!!!",
#       "id": "10152087207029050_12500197",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Kay Sneed",
#        "id": "100000159076535"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:07:12+0000",
#       "message": "Pepsi <3",
#       "id": "10152087207029050_12499932",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "John Adam Thomas",
#        "id": "607059366"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:02:48+0000",
#       "message": "Pepsi and Pizza Hut",
#       "id": "10152087207029050_12499895",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Dave Parsons",
#        "id": "1286274697"
#       },
#       "like_count": 3,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:09:02+0000",
#       "message": "With a 25% increase in profits, Papa John should pay his people a little better, and their healthcare, instead of laying people off and having to give away free pizzas to control the pr damage.....I can't believe Pepsi teamed with this jerk.  I already won't eat his pizza....I'll start drinking Coke as well.",
#       "id": "10152087207029050_12499946",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Dan Sullivan",
#        "id": "560817555"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:07:57+0000",
#       "message": "Support local pizza places, the pizza is better anyway",
#       "id": "10152087207029050_12499936",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Chad Wayne Wilson",
#        "id": "100001859183750"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T19:07:01+0000",
#       "message": "HAVE YOU HEARD WHAT PEPSI IS DOING?????? THOUGHT YOU MAY LIKE TO KNOW....",
#       "id": "10152087207029050_12500934",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Douglas Pilcher",
#        "id": "1562302978"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T18:43:02+0000",
#       "message": "Monday night football and some real pizza!!",
#       "id": "10152087207029050_12500733",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Richard Wade",
#        "id": "505390808"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T18:31:46+0000",
#       "message": "mmmmm cancer in a bottle",
#       "id": "10152087207029050_12500658",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Michael Joseph Masood",
#        "id": "100004644840098"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T18:10:46+0000",
#       "message": "Monday night baseball.",
#       "id": "10152087207029050_12500474",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Betty Izumi",
#        "id": "1586798033"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:50:05+0000",
#       "message": "my favorite is diet pepsi and dominos.",
#       "id": "10152087207029050_12500321",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "William Sadler",
#        "id": "100000487155352"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:40:18+0000",
#       "message": "Ilove pepsi and papa johns , why do they keep closing.",
#       "id": "10152087207029050_12500231",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Linda Moon",
#        "id": "100000642199375"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:33:04+0000",
#       "message": "Pepsi what if u don't have a papa johns in your area",
#       "id": "10152087207029050_12500157",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Gary D Taylor",
#        "id": "1107523192"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:23:38+0000",
#       "message": "SWEET",
#       "id": "10152087207029050_12500059",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Mary Cowan",
#        "id": "100000552790976"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:18:57+0000",
#       "message": "7 Papa Johns shut down in my area",
#       "id": "10152087207029050_12500023",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Kenya Afreh",
#        "id": "100002246490826"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:14:10+0000",
#       "message": "I want it",
#       "id": "10152087207029050_12499990",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Andrea Martin Ireland",
#        "id": "1385153827"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:05:40+0000",
#       "message": "who wants pizza with a guys face on it",
#       "id": "10152087207029050_12499916",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Nancy Calvillo",
#        "id": "100000026181276"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:03:03+0000",
#       "message": "To bad there's no Papa John's Pizza here",
#       "id": "10152087207029050_12499899",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Timothy Milde",
#        "id": "1311095757"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:57:49+0000",
#       "message": "Love my Pepsi(thanks MOM) but way too much Tea for a good pizza!",
#       "id": "10152087207029050_12500376",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Jonathon Cruz-Raygoza",
#        "id": "100003253015013"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:01:09+0000",
#       "message": "uhh... nothing is better than fre pizzaa",
#       "id": "10152087207029050_12499890",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Eric Bon\u00e9",
#        "id": "21726152"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T17:34:03+0000",
#       "message": "Can I just have the Pepsi and donate the cost of a year's worth of shitty/expensive pizza to the employees of his pizza chain who can't afford health insurance and aren't provided any through their employer?",
#       "id": "10152087207029050_12500166",
#       "user_likes": false
#      }
#     ]
#    },
#    "message_tags": {
#     "47": [
#      {
#       "length": 17,
#       "offset": 47,
#       "type": "page",
#       "id": "34703237638",
#       "name": "Papa John's Pizza"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152087323699050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152087323699050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T19:07:01+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Papa John's Pizza",
#       "id": "34703237638"
#      }
#     ]
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10152087207029050&set=a.123490744049.127432.56381779049&type=1&relevant_count=1",
#    "object_id": "10152087207029050",
#    "shares": {
#     "count": 38
#    },
#    "created_time": "2013-10-28T17:00:01+0000",
#    "message": "What's better than Monday night football? FREE Papa John's Pizza for a year, duh! Enter for a chance to WIN right now: http://pep.si/1ccMQ7u",
#    "type": "photo",
#    "id": "56381779049_10152087323699050",
#    "status_type": "added_photos",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "name": "Siau Keith",
#     "id": "100004632221946"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152087257939050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152087257939050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T16:26:54+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T16:26:54+0000",
#    "message": "make my day",
#    "type": "status",
#    "id": "56381779049_10152087257939050"
#   },
#   {
#    "from": {
#     "name": "Jeff Pruitt",
#     "id": "100002374393692"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152087250674050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152087250674050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T16:36:05+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T16:36:05+0000",
#       "message": "Woo! So glad to hear you're a fan. :)",
#       "id": "10152087250674050_31929094",
#       "user_likes": false
#      }
#     ]
#    },
#    "created_time": "2013-10-28T16:22:28+0000",
#    "message": "Cherry Pepsi is the BEST!!!",
#    "type": "status",
#    "id": "56381779049_10152087250674050"
#   },
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-frc3/q71/s480x480/1380516_341261706018534_130349469_n.jpg",
#    "from": {
#     "name": "Tom LeVasseur",
#     "id": "100004041222602"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:22:43+0000",
#       "message": "Thanks for sharing!",
#       "id": "341261706018534_866036",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/341261706018534",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/341261706018534",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T14:22:43+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=341261706018534&set=o.56381779049&type=1",
#    "object_id": "341261706018534",
#    "created_time": "2013-10-28T13:52:25+0000",
#    "message": "Here's a cool Pepsi streetcar from Toronto (1950s).",
#    "type": "photo",
#    "id": "56381779049_341261706018534",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "name": "Tracy Hazard Allen",
#     "id": "702385341"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152086842539050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152086842539050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T14:22:53+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:22:53+0000",
#       "message": "Thanks for your input Tracy! We'll def pass it along.",
#       "id": "10152086842539050_31927685",
#       "user_likes": false
#      }
#     ]
#    },
#    "created_time": "2013-10-28T12:37:41+0000",
#    "message": "Bring back Pepsi Throwback please!",
#    "type": "status",
#    "id": "56381779049_10152086842539050"
#   },
#   {
#    "from": {
#     "name": "Val Damian",
#     "id": "100002629066269"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152086768924050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152086768924050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T11:59:11+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T11:59:11+0000",
#    "message": "Robbing the Choice of a New Generation ! \" vote yes on 522 ! and tell pepsi to stop using GMO\"s in there products.",
#    "type": "status",
#    "id": "56381779049_10152086768924050"
#   },
#   {
#    "from": {
#     "name": "Hisham Mohsen",
#     "id": "648125883"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152086364829050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152086364829050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T07:27:01+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T07:27:01+0000",
#    "message": "Thanx Pepsi for giving us big fat asses :3",
#    "type": "status",
#    "id": "56381779049_10152086364829050"
#   },
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-prn2/q71/s480x480/1383565_381531435313862_43770228_n.jpg",
#    "from": {
#     "name": "Gerardo M Gonzalez",
#     "id": "100003710272512"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:03:22+0000",
#       "message": "Nice photo!! Thanks for sharing. :)",
#       "id": "381531435313862_983539",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/381531435313862",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/381531435313862",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T14:03:22+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "namespace": "fbandroid",
#     "name": "Facebook for Android",
#     "id": "350685531728"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=381531435313862&set=o.56381779049&type=1",
#    "object_id": "381531435313862",
#    "created_time": "2013-10-28T06:03:53+0000",
#    "type": "photo",
#    "id": "56381779049_381531435313862",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-frc3/q75/s480x480/1391967_169058323295505_2011074392_n.jpg",
#    "from": {
#     "name": "Danyelle Hedrick",
#     "id": "100005740149097"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:03:31+0000",
#       "message": "Aww cute!",
#       "id": "169058323295505_145361",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/169058323295505",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/169058323295505",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T14:03:31+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "namespace": "fbiphone",
#     "name": "Facebook for iPhone",
#     "id": "6628568379"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=169058323295505&set=o.56381779049&type=1",
#    "object_id": "169058323295505",
#    "created_time": "2013-10-28T04:43:30+0000",
#    "type": "photo",
#    "id": "56381779049_169058323295505",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "name": "Chuck Henderson",
#     "id": "1585492603"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152086104319050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152086104319050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T14:05:54+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "message_tags": [
#        {
#         "length": 10,
#         "offset": 19,
#         "type": "page",
#         "id": "166794433356457",
#         "name": "Diet Pepsi"
#        }
#       ],
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:05:54+0000",
#       "message": "We <3 you. Go give Diet Pepsi some love too: https://www.facebook.com/dietpepsi",
#       "id": "10152086104319050_31927514",
#       "user_likes": false
#      }
#     ]
#    },
#    "created_time": "2013-10-28T04:22:07+0000",
#    "message": "I Love Diet Pepsi.",
#    "type": "status",
#    "id": "56381779049_10152086104319050"
#   },
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-frc3/q77/s480x480/1378865_10105354428244764_1509499222_n.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDAyMTYzNzg5OTk1",
#       "before": "MTAwMDAyMTYzNzg5OTk1"
#      }
#     },
#     "data": [
#      {
#       "id": "100002163789995",
#       "name": "Kenny Brengle"
#      }
#     ]
#    },
#    "from": {
#     "name": "Veronica Wellein",
#     "id": "9390915"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:06:11+0000",
#       "message": "Awww. We love-- thanks for sharing!",
#       "id": "10105354428244764_49247378",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10105354428244764",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10105354428244764",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T14:06:11+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10105354428244764&set=o.56381779049&type=1",
#    "object_id": "10105354428244764",
#    "created_time": "2013-10-28T04:17:31+0000",
#    "message": "This is a Pepsi household :)",
#    "type": "photo",
#    "id": "56381779049_10105354428244764",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-ash4/q71/s480x480/524667_169040493297288_520296788_n.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDAyMTYzNzg5OTk1",
#       "before": "NTcxMTA4MTA2"
#      }
#     },
#     "data": [
#      {
#       "id": "571108106",
#       "name": "Hanna Wisecarver"
#      },
#      {
#       "id": "100000914536520",
#       "name": "John Ingman"
#      },
#      {
#       "id": "100002163789995",
#       "name": "Kenny Brengle"
#      }
#     ]
#    },
#    "from": {
#     "name": "Danyelle Hedrick",
#     "id": "100005740149097"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "Mg=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:06:28+0000",
#       "message": "Thanks for sharing!",
#       "id": "169040493297288_145371",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Danyelle Hedrick",
#        "id": "100005740149097"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:09:36+0000",
#       "message": "Welcome!",
#       "id": "169040493297288_145377",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/169040493297288",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/169040493297288",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T14:09:36+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "namespace": "fbiphone",
#     "name": "Facebook for iPhone",
#     "id": "6628568379"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=169040493297288&set=o.56381779049&type=1",
#    "object_id": "169040493297288",
#    "created_time": "2013-10-28T02:16:01+0000",
#    "type": "photo",
#    "id": "56381779049_169040493297288",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-prn2/q73/s480x480/1390617_10201810608739418_366058532_n.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDAyMTYzNzg5OTk1",
#       "before": "MTAwMDAyMTYzNzg5OTk1"
#      }
#     },
#     "data": [
#      {
#       "id": "100002163789995",
#       "name": "Kenny Brengle"
#      }
#     ]
#    },
#    "from": {
#     "name": "Jeffrey BodybuiltBullys Sain",
#     "id": "1608161216"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:06:51+0000",
#       "message": "Thanks for sharing!",
#       "id": "10201810608739418_3401376",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10201810608739418",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10201810608739418",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T14:06:51+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10201810608739418&set=o.56381779049&type=1",
#    "object_id": "10201810608739418",
#    "created_time": "2013-10-28T01:44:12+0000",
#    "type": "photo",
#    "id": "56381779049_10201810608739418",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "name": "Justin Clay",
#     "id": "100000338908531"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152085696279050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152085696279050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T14:07:03+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:07:03+0000",
#       "message": "We know the feeling Justin! ;)",
#       "id": "10152085696279050_31927525",
#       "user_likes": false
#      }
#     ]
#    },
#    "created_time": "2013-10-28T00:52:09+0000",
#    "message": "What i Would do for  some Pepsi right now!!!",
#    "type": "status",
#    "id": "56381779049_10152085696279050"
#   },
#   {
#    "from": {
#     "name": "Loretta Nelson-Robinson",
#     "id": "1051837025"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152085392719050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152085392719050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-27T22:32:42+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2013-10-27T22:32:42+0000",
#    "message": "My husband has an idea:  Knowing your sponsorship is so important in so many areas, Nascar being one of them I have a suggestion. How about making special labels for use in areas like Victory Lane where the drinks are being consumed but many times all that is seen is the nutrition facts on the label.  Maybe a label you can stick on so the driver or other athlete doesn't have to worry about how they are holding the bottle. Therefore your brand logo could be seen regardless how the product is being held. Just a thought.  ",
#    "type": "status",
#    "id": "56381779049_10152085392719050"
#   },
#   {
#    "from": {
#     "name": "Michael Henn",
#     "id": "776998929"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152085392179050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152085392179050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-27T22:32:23+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2013-10-27T22:32:23+0000",
#    "message": "Hey Pepsi, I\u2019m standing with orangutans, and I can\u2019t stand by brands that use Conflict Palm Oil. Demand responsible palm oil from your suppliers and eliminate Conflict Palm Oil from your products. The power is #InYourPalm.",
#    "type": "status",
#    "id": "56381779049_10152085392179050"
#   },
#   {
#    "from": {
#     "name": "Susan Wisniewski Quinn",
#     "id": "1600754670"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152085203279050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10152085203279050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-27T20:57:51+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "created_time": "2013-10-27T20:57:51+0000",
#    "message": "Is there a Pepsi template for pumpkin carving??\n",
#    "type": "status",
#    "id": "56381779049_10152085203279050"
#   },
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-frc3/q71/s480x480/1391632_755898761091903_287945740_n.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDAyMTYzNzg5OTk1",
#       "before": "MTAwMDAyMTYzNzg5OTk1"
#      }
#     },
#     "data": [
#      {
#       "id": "100002163789995",
#       "name": "Kenny Brengle"
#      }
#     ]
#    },
#    "from": {
#     "name": "Angela Barrett Gray",
#     "id": "100000153588065"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MQ==",
#       "before": "MQ=="
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "category": "Food/beverages",
#        "name": "Pepsi",
#        "id": "56381779049"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T14:09:37+0000",
#       "message": "Hi Angela, sorry to hear about this. You can report this anonymously through our Speak Up number at 1-866-729-4888.",
#       "id": "755898761091903_3091315",
#       "user_likes": false
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/755898761091903",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/755898761091903",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T14:09:37+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=755898761091903&set=o.56381779049&type=1",
#    "object_id": "755898761091903",
#    "created_time": "2013-10-27T19:31:31+0000",
#    "message": "Thanks for laying off my Dad right here at the holidays ! He was a hard worker and faithful employee with many years under his belt. You didn't even give him but one day notice ! Really, This is how you treat your employee's ? My parents are going to loose their house and at the age of 61 it is hard to pick up and find another job. I am officially a COKE drinker for life ! Disappointed in you....",
#    "type": "photo",
#    "id": "56381779049_755898761091903",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://fbexternal-a.akamaihd.net/safe_image.php?d=AQCEefUTNZxO56d5&w=154&h=154&url=http%3A%2F%2Fwww.takepart.com%2Fsites%2Fdefault%2Ffiles%2Fmindful.jpg",
#    "from": {
#     "name": "William Winters",
#     "id": "100000051796556"
#    },
#    "name": "Introducing the First Non-GMO Meat Label",
#    "caption": "www.takepart.com",
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/686685008009886",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/686685008009886",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-27T18:52:17+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Pepsi",
#       "id": "56381779049"
#      }
#     ]
#    },
#    "link": "http://www.takepart.com/article/2013/06/21/first-non-gmo-meat-label",
#    "created_time": "2013-10-27T18:52:17+0000",
#    "message": "It can be done.\nhttp://www.takepart.com/article/2013/06/21/first-non-gmo-meat-label",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yq/r/SC2ZmEkfI-X.png",
#    "type": "link",
#    "id": "56381779049_686685008009886",
#    "description": "The new label certifies that meat and egg products are produced without the use of genetically engineered feed."
#   },
#   {
#    "picture": "https://fbcdn-photos-a-a.akamaihd.net/hphotos-ak-ash3/1378637_10152084675864050_1886878758_s.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTQwODg4NzE5NQ==",
#       "before": "MTAwMDAyNDU0MzQ5OTc5"
#      },
#      "next": "https://graph.facebook.com/56381779049_10152084675989050/likes?access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&limit=25&after=MTQwODg4NzE5NQ%3D%3D"
#     },
#     "data": [
#      {
#       "id": "100002454349979",
#       "name": "Charanda Arnold"
#      },
#      {
#       "id": "100000190865084",
#       "name": "Sarah Kelly"
#      },
#      {
#       "id": "100001238825776",
#       "name": "Ian Ruder"
#      },
#      {
#       "id": "668273290",
#       "name": "Vincentia Hunter"
#      },
#      {
#       "id": "100002081949885",
#       "name": "Gary Green"
#      },
#      {
#       "id": "1322235457",
#       "name": "Rebecca Cartee"
#      },
#      {
#       "id": "100000266960715",
#       "name": "Debra Levanda"
#      },
#      {
#       "id": "100004415828954",
#       "name": "Becky Gates"
#      },
#      {
#       "id": "1663547456",
#       "name": "Pat Duffiney"
#      },
#      {
#       "id": "100005168520950",
#       "name": "Ken Frandsen"
#      },
#      {
#       "id": "100001148146772",
#       "name": "Ashley Harlan"
#      },
#      {
#       "id": "100002683292200",
#       "name": "Lillian Martha Compo"
#      },
#      {
#       "id": "100001179174198",
#       "name": "Roger Romedy"
#      },
#      {
#       "id": "100005308657209",
#       "name": "Allison Baggarly"
#      },
#      {
#       "id": "100002301427410",
#       "name": "Amelia Lipe"
#      },
#      {
#       "id": "100002555727302",
#       "name": "Valarie Miller"
#      },
#      {
#       "id": "1471930717",
#       "name": "Lori Peper Shaffer"
#      },
#      {
#       "id": "100002443190463",
#       "name": "Eulogia Bams"
#      },
#      {
#       "id": "100001448918946",
#       "name": "Rhiannon Foreman"
#      },
#      {
#       "id": "100006259629323",
#       "name": "Seki Abedinovic"
#      },
#      {
#       "id": "100001336410174",
#       "name": "Pamela Wright"
#      },
#      {
#       "id": "1395999100",
#       "name": "Kayskin Marks"
#      },
#      {
#       "id": "100002082085449",
#       "name": "Jess Weldon"
#      },
#      {
#       "id": "100004175316986",
#       "name": "Joanne Diaz"
#      },
#      {
#       "id": "1408887195",
#       "name": "Karen Utley"
#      }
#     ]
#    },
#    "from": {
#     "category": "Food/beverages",
#     "name": "Pepsi",
#     "id": "56381779049"
#    },
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "MTQ=",
#       "before": "Mzg="
#      },
#      "next": "https://graph.facebook.com/56381779049_10152084675989050/comments?access_token=CAACEdEose0cBACuYzBBn1iI349xnqkAd519r4U4xo1TOOM2e427x1mMx4CzLiC5IiKCN74UZCQYdNYvmBmCKCNcfW3ZAU4ZBUUqgZBylydV1QwhWd89pIDdEBZCUZCIhrbBLa5bkKppe2EsNOXZACpFo80RZAjSpyGwoMFbGESsNvEArouELvz5twSTZBd7L0qLoZD&limit=25&after=MTQ%3D"
#     },
#     "data": [
#      {
#       "from": {
#        "name": "Will Gardiner",
#        "id": "885705272"
#       },
#       "like_count": 2,
#       "can_remove": false,
#       "created_time": "2013-10-27T18:05:23+0000",
#       "message": "How does one acquire these goal posts?",
#       "id": "10152084675864050_12489820",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Joann Block",
#        "id": "100004924393497"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-10-27T17:45:26+0000",
#       "message": "I want those & the Lil Pepsi cans....can u tell me were I can get them.....Thanks......:) :)",
#       "id": "10152084675864050_12489630",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Yogi Kesl",
#        "id": "100000735570803"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-28T04:43:23+0000",
#       "message": "It's up. It's good. And the Pepsi is gone !!!! I love that stuff.",
#       "id": "10152084675864050_12495688",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Marlene Manske",
#        "id": "1292422557"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-27T17:31:32+0000",
#       "message": "I need those!  Where can I get them?",
#       "id": "10152084675864050_12489498",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Joann Block",
#        "id": "100004924393497"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-27T17:47:02+0000",
#       "message": "<3 <3 my (((((((( PEPSI )))))))",
#       "id": "10152084675864050_12489648",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "ConJery ConJery",
#        "id": "100001827728626"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-27T17:44:04+0000",
#       "message": "Go Boy's !!",
#       "id": "10152084675864050_12489621",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Larry Brooks",
#        "id": "100000264720620"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-27T22:46:37+0000",
#       "message": "I have a lot of Pepsi stuff for sale. You name it I have it.",
#       "id": "10152084675864050_12492501",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Rebecca Charles",
#        "id": "1336751069"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-10-27T19:59:56+0000",
#       "message": "Love Pepsi!",
#       "id": "10152084675864050_12490897",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Angie Vallery",
#        "id": "100003246041848"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-10-27T19:20:46+0000",
#       "message": "We are going to the game Monday night to watch the St.louis Rams vs  Seattle Seahawks & I'm a Rams fan & my boyfriend is a Seahawks fan because he's from Washington so it should be interesting.LOL we will be in the box by the field so I'm super excited.I Drink Cherry Pepsi EVERYDAY & that's all I drink!!!#Truestory I wld love the Pepsi goalies,so we can get our own game on!!!How fun \u2764Them!!",
#       "id": "10152084675864050_12490527",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Joanne Houston-fath",
#        "id": "100000289808153"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "created_time": "2013-10-27T19:06:28+0000",
#       "message": "Mine never came!!!!  @Pepsi! :/",
#       "id": "10152084675864050_12490386",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Mary Workman",
#        "id": "100000930520484"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "created_time": "2013-10-27T18:16:03+0000",
#       "message": "im addicted to pepsi lol",
#       "id": "10152084675864050_12489914",
#       "user_likes": false
#      },
#      {
#       "from": {
#        "name": "Amy Lamm",
#        "id": "100001412082711"
#       },
#       "message_tags": [
#        {
#         "length": 10,
# ...
#    "id": "40796308305_635098279846585",
#    "description": "MAIS UM LAN\u00c7AMENTO OFICIAL EM BREVE NO YOUTUBE CONFEREM A PREVIA FAMILIA COMPARTILHE NO FACEBOOK E EM TODAS AS REDES SOCIAIS DA ESSA FORTALECIDA PRA NOIS.. A..."
#   },
#   {
#    "from": {
#     "name": "Michelle Midoryy",
#     "id": "100007008841904"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770461123306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770461123306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T18:44:47+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T18:44:47+0000",
#    "message": "\nLIMPO SEU NOME DO SPC SERASA SEM PAGAR AS CONTAS\nLimpe o seu nome em 24 horas, sem precisar pagar suas contas...\nIsso mesmo, tenha uma vida nova, com nome limpo, com cr\u00e9dito em bancos, financiadoras\ne lojas sem precisar pagar suas contas antigas com os juros abusivos.\nEnvie um e-mail para creditook@gmail.com e tire todas as suas d\u00favidas.\nRenove sua vida do jeito mais f\u00e1cil, r\u00e1pido e seguro!\n\nEnvie um e-mail para\ncreditook@gmail.com\n\ne tire todas as suas d\u00favidas.\nAguardamos seu retorno, Obrigado!",
#    "type": "status",
#    "id": "40796308305_10152770461123306"
#   },
#   {
#    "from": {
#     "name": "Bwambale Rhk Jerome",
#     "id": "100003991602236"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770460988306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770460988306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T18:44:41+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T18:44:41+0000",
#    "message": "#cokeconnect is biased no winner from western ug i.e kasese,bushenyi fortportal ",
#    "type": "status",
#    "id": "40796308305_10152770460988306"
#   },
#   {
#    "from": {
#     "category": "Comedian",
#     "name": "Humorindo",
#     "id": "391962510898499"
#    },
#    "message_tags": {
#     "29": [
#      {
#       "length": 9,
#       "offset": 29,
#       "type": "page",
#       "id": "391962510898499",
#       "name": "Humorindo"
#      }
#     ]
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770459628306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770459628306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T18:43:47+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Comedian",
#       "name": "Humorindo",
#       "id": "391962510898499"
#      },
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T18:43:47+0000",
#    "message": "Quero ve todo mundo curtindo Humorindo!!!!!\r\nVamo curti geral ae!!",
#    "type": "status",
#    "id": "40796308305_10152770459628306"
#   },
#   {
#    "from": {
#     "name": "Mukosa Moses",
#     "id": "100005948647402"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770436008306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770436008306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T18:31:09+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T18:31:09+0000",
#    "message": "Oh, what a wonderful moment with coke! Iwish more proms are given",
#    "type": "status",
#    "id": "40796308305_10152770436008306"
#   },
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-prn2/q73/s480x480/1393174_547437958682653_116731778_n.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAwMDAxODExMDg3NTE1",
#       "before": "MTAwMDA0ODQxMzc1OTc4"
#      }
#     },
#     "data": [
#      {
#       "id": "100004841375978",
#       "name": "G\u0103bi\u021bu Latt\u00e9"
#      },
#      {
#       "id": "100000324971161",
#       "name": "Bianca Maria"
#      },
#      {
#       "id": "100004179311401",
#       "name": "Doody"
#      },
#      {
#       "id": "100000293892979",
#       "name": "Ioana Catalina"
#      },
#      {
#       "id": "100003954846670",
#       "name": "Sumit Motiu"
#      },
#      {
#       "id": "100001654557840",
#       "name": "Maria Anastasia"
#      },
#      {
#       "id": "100001615749145",
#       "name": "Kira B\u0103"
#      },
#      {
#       "id": "100001587194774",
#       "name": "Alexa Mtfk"
#      },
#      {
#       "id": "100000542693540",
#       "name": "Aida Vladoiu"
#      },
#      {
#       "id": "100002510842508",
#       "name": "Gabii B\u0103\u0103"
#      },
#      {
#       "id": "100001811087515",
#       "name": "Madalina Alexandra"
#      }
#     ]
#    },
#    "from": {
#     "name": "Catalin R. Blade",
#     "id": "100002493615522"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/547437958682653",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/547437958682653",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T18:30:25+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=547437958682653&set=o.40796308305&type=1",
#    "object_id": "547437958682653",
#    "created_time": "2013-10-28T18:30:25+0000",
#    "message": "#caloriifericite",
#    "type": "photo",
#    "id": "40796308305_547437958682653",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-a.xx.fbcdn.net/hphotos-frc1/q71/s480x480/578043_10202260179971060_550523303_n.jpg",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTM4NzQyNDIzOA==",
#       "before": "MTM4NzQyNDIzOA=="
#      }
#     },
#     "data": [
#      {
#       "id": "1387424238",
#       "name": "Marcel Nofz"
#      }
#     ]
#    },
#    "from": {
#     "name": "Marcel Nofz",
#     "id": "1387424238"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10202260179971060",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10202260179971060",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T18:19:57+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=10202260179971060&set=o.40796308305&type=1",
#    "object_id": "10202260179971060",
#    "created_time": "2013-10-28T18:19:57+0000",
#    "message": "Remember Berlin 1936!",
#    "type": "photo",
#    "id": "40796308305_10202260179971060",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "picture": "https://scontent-b.xx.fbcdn.net/hphotos-ash4/q84/s480x480/1380354_693239067354511_421781353_n.jpg",
#    "from": {
#     "category": "Food/grocery",
#     "name": "Chefs Bakery & Confectionery",
#     "id": "314997665178655"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/693239067354511",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/693239067354511",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T18:16:31+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "application": {
#     "name": "Photos",
#     "id": "2305272732"
#    },
#    "link": "https://www.facebook.com/photo.php?fbid=693239067354511&set=o.40796308305&type=1",
#    "object_id": "693239067354511",
#    "created_time": "2013-10-28T18:16:31+0000",
#    "message": "we made this in Nepal!",
#    "type": "photo",
#    "id": "40796308305_693239067354511",
#    "icon": "https://fbstatic-a.akamaihd.net/rsrc.php/v2/yz/r/StEh3RhPvjk.gif"
#   },
#   {
#    "from": {
#     "name": "Rosana Mendes Santos",
#     "id": "100002321390686"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770397873306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770397873306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T18:13:04+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T18:13:04+0000",
#    "message": "Boa tarde! Gostaria que vcs se manifestassem  sobre notici\u00e1rios sobre res\u00edduos de rato no refrigerante .Se foi uma indisplicenncia doe algum funcion\u00e1rio ou uma fraude....So posso acreditar numa dessas hip\u00f3teses,  j\u00e1 adoro esse refrigerante, nem posso imaginar sobre falta de higiene com esse produto. Aguardo noticias.\n",
#    "type": "status",
#    "id": "40796308305_10152770397873306"
#   },
#   {
#    "from": {
#     "name": "Agus Tin",
#     "id": "100000459800606"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770384713306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770384713306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T18:05:28+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T18:05:28+0000",
#    "message": "DEJEN DE TOMAR ESTE VENENO !!!! MATA GENTE TODOS LOS A\u00d1OS !",
#    "type": "status",
#    "id": "40796308305_10152770384713306"
#   },
#   {
#    "from": {
#     "name": "Mujas Wilberforce",
#     "id": "100001147657752"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770381158306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770381158306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T18:03:20+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T18:03:20+0000",
#    "message": "How do they win banage",
#    "type": "status",
#    "id": "40796308305_10152770381158306"
#   },
#   {
#    "from": {
#     "name": "Namara Bannet",
#     "id": "100001313599629"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770348673306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770348673306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T17:46:23+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T17:46:23+0000",
#    "message": "its ma cool drink",
#    "type": "status",
#    "id": "40796308305_10152770348673306"
#   },
#   {
#    "from": {
#     "name": "Francilene Oliveira",
#     "id": "100006505775724"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770326723306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770326723306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T17:35:14+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T17:35:14+0000",
#    "message": "Esa e boa pra tira aquela ressaca ",
#    "type": "status",
#    "id": "40796308305_10152770326723306"
#   },
#   {
#    "application": {
#     "name": "Facebook for Every Phone",
#     "id": "139682082719810"
#    },
#    "from": {
#     "name": "De Bruno Duncan",
#     "id": "100004020338318"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770325438306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770325438306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T17:34:21+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T17:34:21+0000",
#    "message": "Uii thx craizy.hu agreex with me dat cocacola iz testy",
#    "type": "status",
#    "id": "40796308305_10152770325438306"
#   },
#   {
#    "from": {
#     "name": "Al Varez Van Rend",
#     "id": "100006807392948"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770316723306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770316723306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T17:29:14+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T17:29:14+0000",
#    "message": "Nnton bOlA\r\nsmbIl mNum\r\ncoca-cola\r\n\n#sAdApP",
#    "type": "status",
#    "id": "40796308305_10152770316723306"
#   },
#   {
#    "from": {
#     "name": "Francesco Arca",
#     "id": "100002940604815"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770301248306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770301248306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T17:21:28+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "place": {
#     "location": {
#      "latitude": 43.3167,
#      "street": "",
#      "longitude": 11.35,
#      "zip": ""
#     },
#     "id": "105751109465081",
#     "name": "Siena, Italy"
#    },
#    "created_time": "2013-10-28T17:21:28+0000",
#    "message": "GOOOOOOOOOOOOOOOOOOO!!",
#    "type": "status",
#    "id": "40796308305_10152770301248306"
#   },
#   {
#    "from": {
#     "name": "Galley Sula",
#     "id": "100005756942493"
#    },
#    "privacy": {
#     "value": ""
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770286103306",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/40796308305/posts/10152770286103306",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2013-10-28T17:15:03+0000",
#    "to": {
#     "data": [
#      {
#       "category": "Food/beverages",
#       "name": "Coca-Cola",
#       "id": "40796308305"
#      }
#     ]
#    },
#    "created_time": "2013-10-28T17:15:03+0000",
#    "message": "mwe banange lets open the happeyness with coca-cola.",
#    "type": "status",
#    "id": "40796308305_10152770286103306"
#   }
#  ]
# }
# {
#  "data": []
# }

# %% [markdown]
# ## Example 7. Querying for all of your friends' likes

# %%
# First, let's query for all of the likes in your social
# network and store them in a slightly more convenient
# data structure as a dictionary keyed on each friend's
# name. We'll use a dictionary comprehension to iterate
# over the friends and build up the likes in an intuitive
# way, although the new "field expansion" feature could 
# technically do the job in one fell swoop as follows:
#
# g.get_object('me', fields='id,name,friends.fields(id,name,likes)')
#
# See Appendix C for more information on Python tips such as
# dictionary comprehensions

friends = g.get_connections("me", "friends")['data']

likes = { friend['name'] : g.get_connections(friend['id'], "likes")['data'] 
          for friend in friends }

print likes
# Out:
# {u'Amanda Edmonds': [{u'category': u'Clothing', u'created_time': u'2010-08-24T16:36:47+0000', u'name': u'Tea Collection', u'id': u'129812660326'}, {u'category': u'Public figure', u'created_time': u'2009-12-08T23:15:25+0000', u'name': u'Elinor Malendoski', u'category_list': [{u'id': u'1602', u'name': u'Public Figure'}], u'id': u'218700235021'}], u'Ian Krantz': [{u'category': u'Health/wellness website', u'created_time': u'2013-06-18T18:42:42+0000', u'name': u'Philly.com Healthy Living', u'category_list': [{u'id': u'2707', u'name': u'Health/Wellness Website'}], u'id': u'162732330537012'}, {u'category': u'Product/service', u'created_time': u'2012-11-16T00:06:51+0000', u'name': u'JetPens.com', u'id': u'44054262248'}, {u'category': u'News/media website', u'created_time': u'2011-10-08T16:07:44+0000', u'name': u'Philadelphia Inquirer', u'id': u'23332703568'}, {u'category': u'Media/news/publishing', u'created_time': u'2011-07-06T16:51:08+0000', u'name': u'The New York Times', u'category_list': [{u'id': u'108366235907857', u'name': u'Newspaper'}], u'id': u'5281959998'}, {u'category': u'Business/economy website', u'created_time': u'2011-02-17T12:32:39+0000', u'name': u'Despair.com', u'id': u'6481756842'}, {u'category': u'Magazine', u'created_time': u'2010-12-14T16:37:22+0000', u'name': u'strategy+business magazine', u'category_list': [{u'id': u'1307', u'name': u'Magazine'}], u'id': u'108266937897'}, {u'category': u'Company', u'created_time': u'2010-03-16T01:44:15+0000', u'name': u'Weavers Way Co-op', u'id': u'320069273919'}, {u'category': u'Musician/band', u'created_time': u'2010-03-07T21:59:01+0000', u'name': u'Jeff Snake Greenberg', u'id': u'122015579345'}, {u'category': u'Musician/band', u'created_time': u'2010-01-11T20:08:23+0000', u'name': u'Billy Bragg', u'id': u'44905697470'}, {u'category': u'Author', u'created_time': u'2009-12-31T07:02:08+0000', u'name': u'Michael Wex', u'id': u'110374929551'}, {u'category': u'Non-profit organization', u'created_time': u'2009-12-04T19:02:53+0000', u'name': u'West Philly Hybrid X Team', u'category_list': [{u'id': u'2603', u'name': u'Non-Profit Organization'}], u'id': u'59535503931'}, {u'category': u'Musician/band', u'created_time': u'2009-07-17T06:03:54+0000', u'name': u'Dancefloor Diplomacy', u'id': u'89890587079'}, {u'category': u'Community', u'created_time': u'2009-05-16T12:55:02+0000', u'name': u'*freeculturemusic', u'id': u'29204064979'}, {u'category': u'Media/news/publishing', u'created_time': u'2009-01-07T13:47:59+0000', u'name': u'NPR', u'category_list': [{u'id': u'169056916473899', u'name': u'Broadcasting & Media Production'}, {u'id': u'177721448951559', u'name': u'Workplace & Office'}], u'id': u'10643211755'}, {u'category': u'Community', u'created_time': u'2008-12-31T02:49:26+0000', u'name': u'Rats', u'id': u'6784832873'}], u'Elyse Hornig Belanger': [{u'category': u'Musician/band', u'created_time': u'2013-10-02T18:48:11+0000', u'name': u'Stephanie Anne Johnson', u'id': u'128052767388920'}, {u'category': u'Musician/band', u'created_time': u'2013-09-22T17:34:53+0000', u'name': u'Classical Music Humor', u'id': u'207019572653107'}, {u'category': u'Entertainment website', u'created_time': u'2013-09-22T16:55:00+0000', u'name': u'oh im sorry, i forgot i only exist to you when you need something from me', u'id': u'109657199061503'}, {u'category': u'Musician/band', u'created_time': u'2013-09-16T03:34:04+0000', u'name': u'The Online Piano & Violin Tutor', u'id': u'286077151455100'}, {u'category': u'Writer', u'created_time': u'2012-12-29T01:06:01+0000', u'name': u'Anthony Trollope', u'id': u'366853793411073'}, {u'category': u'Author', u'created_time': u'2012-04-12T15:11:49+0000', u'name': u'Alexandre Dumas, p\xe8re', u'id': u'236573963101171'}, {u'category': u'Author', u'created_time': u'2012-01-21T07:49:36+0000', u'name': u'Jane Austen', u'id': u'344695912224001'}, {u'category': u'Games/toys', u'created_time': u'2011-07-14T04:51:01+0000', u'name': u'Reindeer', u'id': u'174157882607678'}, {u'catego ...

# %% [markdown]
# ## Example 8. Calculating the most popular likes among your friends

# %%
# Analyze all likes from friendships for frequency

# pip install prettytable
from prettytable import PrettyTable
from collections import Counter
friends_likes = Counter([like['name']
                         for friend in likes 
                           for like in likes[friend]
                               if like.get('name')])

pt = PrettyTable(field_names=['Name', 'Freq'])
pt.align['Name'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(fl) for fl in friends_likes.most_common(10) ]

print 'Top 10 likes amongst friends'
print pt
# Out:
# Top 10 likes amongst friends
# +---------------------------------------------+------+
# | Name                                        | Freq |
# +---------------------------------------------+------+
# | Amazon.com                                  |    9 |
# | MindTap                                     |    6 |
# | George Takei                                |    6 |
# | eBooks.com                                  |    5 |
# | Upworthy                                    |    5 |
# | Economics at South-Western Cengage Learning |    4 |
# | CengageBrain.com                            |    4 |
# | 4LTR Press                                  |    4 |
# | Blade Runner                                |    4 |
# | The Beatles                                 |    4 |
# +---------------------------------------------+------+

# %% [markdown]
# ## Example 9. Calculating the most popular categories for likes among your friends

# %%
# Analyze all like categories by frequency

friends_likes_categories = Counter([like['category'] 
                                    for friend in likes 
                                      for like in likes[friend]])

pt = PrettyTable(field_names=['Category', 'Freq'])
pt.align['Category'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(flc) for flc in friends_likes_categories.most_common(10) ]

print "Top 10 like categories for friends"
print pt
# Out:
# Top 10 like categories for friends
# +-------------------------+------+
# | Category                | Freq |
# +-------------------------+------+
# | Musician/band           |  178 |
# | Local business          |  148 |
# | Community               |  143 |
# | Non-profit organization |  120 |
# | Movie                   |   97 |
# | Product/service         |   96 |
# | Company                 |   91 |
# | Public figure           |   88 |
# | Media/news/publishing   |   87 |
# | Author                  |   83 |
# +-------------------------+------+

# %% [markdown]
# ## Example 10. Calculating the number of likes for each friend and sorting by frequency

# %%
# Build a frequency distribution of number of likes by 
# friend with a dictionary comprehension and sort it in 
# descending order

from operator import itemgetter

num_likes_by_friend = { friend : len(likes[friend]) 
                        for friend in likes }


pt = PrettyTable(field_names=['Friend', 'Num Likes'])
pt.align['Friend'], pt.align['Num Likes'] = 'l', 'r'
[ pt.add_row(nlbf) 
  for nlbf in sorted(num_likes_by_friend.items(), 
                     key=itemgetter(1), 
                     reverse=True) ]

print "Number of likes per friend"
print pt
# Out:
# Number of likes per friend
# +----------------------------+-----------+
# | Friend                     | Num Likes |
# +----------------------------+-----------+
# | Elyse Hornig Belanger      |        25 |
# | Alberto Precht Rorris      |        25 |
# | Mitchell Davis             |        25 |
# | Joanne Alvord              |        25 |
# | Dawn Santorella            |        25 |
# | Kate Tentler               |        25 |
# | Karen Fetty                |        25 |
# | Tad Metzger                |        25 |
# | Tim Linerud                |        25 |
# | Kelley L. Allen            |        25 |
# | Pandora Mather-Lees        |        25 |
# | Gia Young                  |        25 |
# | Malle Vallik               |        25 |
# | Tom Miller                 |        25 |
# | Kevin McKiernan            |        25 |
# | Kari Paulson               |        25 |
# | J. Kirby Best              |        25 |
# | Gwyn Headley               |        25 |
# | Kenneth Brooks             |        25 |
# | Jonathan Guttenberg        |        25 |
# | Sharon Brown Furbee        |        25 |
# | Iris L. Hanney             |        25 |
# | Alex Albin                 |        25 |
# | Tom Grega                  |        25 |
# | Ann Marie Lamb             |        25 |
# | Dan Silverburg             |        25 |
# | Barry Gayheart             |        25 |
# | Melanie Roberts            |        25 |
# | Konrad Hilbers             |        25 |
# | Asheesh Birla              |        25 |
# | Steve Potash               |        25 |
# | Jonathan Stowe             |        25 |
# | Jake Rauscher              |        25 |
# | Pam Laycock                |        25 |
# | Laura Pople                |        25 |
# | Laura Nixon Dawson         |        25 |
# | Terri Coats                |        25 |
# | Tomomi Melton              |        25 |
# | Lisa Herling               |        25 |
# | Lindsay Stanley            |        25 |
# | Myles C. Thompson          |        25 |
# | Kay Spencer                |        25 |
# | Christopher Hyams Hart     |        25 |
# | Bob Diforio                |        25 |
# | Kara Anne                  |        25 |
# | Denay Wilding Knope        |        25 |
# | Ina Gottinger              |        25 |
# | Margaret McIntyre          |        25 |
# | Dennis Britton             |        25 |
# | Ashley Gordon              |        25 |
# | Frank Lyman                |        25 |
# | Carolyn Pittis             |        25 |
# | Steve Kotrch               |        25 |
# | Band Cathy                 |        25 |
# | Adam Smith                 |        25 |
# | Katrine Rosseland Johansen |        25 |
# | Siobhan Padgett            |        25 |
# | Melissa Loder              |        25 |
# | Christian Smythe           |        25 |
# | Matt Brooks                |        25 |
# | Lois Stitt                 |        25 |
# | Karen Birnie Garzon        |        25 |
# | Roger S. Williams          |        25 |
# | Peter McCarthy             |        25 |
# | Lynn Butler                |        25 |
# | Maggie Wright              |        25 |
# | John Ambrose               |        25 |
# | Piero Chiodo               |        25 |
# | Rob Berkley                |        25 |
# | David Taylor               |        25 |
# | Alison Pendergast          |        25 |
# | Mike Shatzkin              |        25 |
# | Joe Gallagher              |        25 |
# | Pat Waldo                  |        25 |
# | Sharra Lebov               |        25 |
# | Griffin Rauscher           |        25 |
# | Kristin Syvertson- Chase   |        25 |
# | Adam Gaber                 |        25 |
# | Andrea Kudzia              |        25 |
# | Tracy Augustine            |        25 |
# | Ritu Raj                   |        25 |
# | Ralph Zerbonia             |        25 |
# | David Wilk                 |        25 |
# | Tracy Leone Ritter         |        25 |
# | Ed Solomon                 |        23 |
# | Sol Rosenberg              |        22 |
# | David Geppert              |        21 |
# | Matt Hong                  |        20 |
# | Thierry Brethes            |        19 |
# | Greg Bayer                 |        18 |
# | Susan Kahelin Badger       |        18 |
# | Bob Moschetto              |        17 |
# | Ian Krantz                 |        15 |
# | Fionnuala Duggan           |        15 |
# | Helen Mason                |        15 |
# | John Warren                |        15 |
# | Peggy Porter Mclaughlin    |        14 |
# | Joseph J. Esposito         |        14 |
# | Mark Ealden                |        14 |
# | Michelle Julet             |        13 |
# | Sheila Christine Savage    |        12 |
# | Erin Hixson                |        12 |
# | Lorraine Shanley           |        12 |
# | Shah Karim                 |        11 |
# | Roger Sperberg             |        11 |
# | Lois Masini                |        10 |
# | Robin Lucas                |        10 |
# | Heidi Gladitsch Keeney     |         9 |
# | Stephen Fredette           |         9 |
# | Jack Calhoun               |         9 |
# | Jennifer Mitchell          |         8 |
# | Dreis Van Landuyt          |         7 |
# | James Lichtenberg          |         7 |
# | Mabelle Montufar-Galarza   |         7 |
# | Harry L. Spencer           |         7 |
# | Mary Duffy Braun           |         7 |
# | Theresa Horner             |         6 |
# | Stephen James Cole         |         6 |
# | Joy Mecca Arditti          |         6 |
# | Dave Rauscher              |         5 |
# | Andrew Grabois             |         5 |
# | Jennifer Wahi              |         5 |
# | Rebecca Graveline Doane    |         5 |
# | Brian Napack               |         4 |
# | Karen Fikri                |         4 |
# | Elizabeth C Mackey         |         4 |
# | Sonia Thind                |         3 |
# | Peter Luzmore              |         3 |
# | Cory Juhl                  |         3 |
# | Amanda Edmonds             |         2 |
# | Henry Topping              |         2 |
# | Rob Reynolds               |         2 |
# | Peter Balis                |         2 |
# | Lorraine Carlson           |         1 |
# | Judy Duffy                 |         1 |
# | Carrie Willicome           |         1 |
# | Larry Norton               |         1 |
# | Sacha Laustsen O'Flynn     |         0 |
# | Neil Marquardt             |         0 |
# | Iris Blasi                 |         0 |
# | Alicia Wise                |         0 |
# | William Gilbert            |         0 |
# | Lee Fyock                  |         0 |
# | Mark Bide                  |         0 |
# | Fran Toolan                |         0 |
# | Sanae Benoit               |         0 |
# | Jeremy Ettinghausen        |         0 |
# | Jon Noring                 |         0 |
# | Mimi McLaughlin            |         0 |
# | Mike Violano               |         0 |
# | Megan Lamb                 |         0 |
# | Matthew Stitt              |         0 |
# | Carol Chiodo               |         0 |
# | Jurgen Pauquet             |         0 |
# | Mark Reichelt              |         0 |
# | Mark Blair                 |         0 |
# | Chelsea Vaughn Showalter   |         0 |
# | Marc Calvanico             |         0 |
# | Lara O'Loan                |         0 |
# | Oliver Mac Cathmhaoil      |         0 |
# | Philippa Lehar Sakos       |         0 |
# | Nichols Bleckley           |         0 |
# | Meg Fisher                 |         0 |
# | Kathleen Doody Gallagher   |         0 |
# | Paulanne Queen             |         0 |
# | Marguerite Faraco Cardinal |         0 |
# | Liz Koons Lynn             |         0 |
# | Caroline Vanderlip         |         0 |
# | Caitlin Stitt              |         0 |
# | Keith Titan                |         0 |
# | Becca Goldthwaite          |         0 |
# | Erin McElwain Wetzel       |         0 |
# | Claire Israel              |         0 |
# | James G. Robinson          |         0 |
# | Carol Moran                |         0 |
# | Steve Sieck                |         0 |
# | Mark Arditti               |         0 |
# | PJ Boardman                |         0 |
# | Heather Madsen             |         0 |
# | Margaret Witten            |         0 |
# | Cindy Pummer Rauscher      |         0 |
# | Andrew Willis              |         0 |
# | Linh Đỗ                    |         0 |
# | Peter Rogers               |         0 |
# | Suzi Cole                  |         0 |
# | Megan Brooks               |         0 |
# | Kelly A. Quin              |         0 |
# +----------------------------+-----------+

# %% [markdown]
# ## Example 11. Finding common likes between an ego and its friendships in a social network

# %%
# Which of your likes are in common with which friends?
my_likes = [ like['name'] 
             for like in g.get_connections("me", "likes")['data'] ]

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((ml,)) for ml in my_likes ]
print "My likes"
print pt

# Use the set intersection as represented by the ampersand
# operator to find common likes.

common_likes = list(set(my_likes) & set(friends_likes))

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((cl,)) for cl in common_likes ]
print
print "My common likes with friends"
print pt
# Out:
# My likes
# +----------------------------------------------------+
# | Name                                               |
# +----------------------------------------------------+
# | eBooks.com                                         |
# | CS215: Pathway That Can Use Two Nodes - Algorithms |
# | Udacity: CS 101                                    |
# | OrchestratorMail                                   |
# | Saugatuck Grain and Grape                          |
# | DriveSafe.ly                                       |
# | O'Reilly Tools of Change for Publishing            |
# +----------------------------------------------------+
#
# My common likes with friends
# +--------------+
# | Name         |
# +--------------+
# | DriveSafe.ly |
# | eBooks.com   |
# +--------------+

# %% [markdown]
# ## Example 12. Calculating the friends most similar to an ego in a social network

# %%
import matplotlib.pyplot as plt
import numpy

# Which of your friends like things that you like?

similar_friends = [ (friend, friend_like['name']) 
                     for friend, friend_likes in likes.items()
                       for friend_like in friend_likes
                         if friend_like.get('name') in common_likes ]


# Filter out any possible duplicates that could occur

ranked_friends = Counter([ friend for (friend, like) in list(set(similar_friends)) ])


pt = PrettyTable(field_names=["Friend", "Common Likes"])
pt.align["Friend"], pt.align["Common Likes"] = 'l', 'r'
[ pt.add_row(rf) 
  for rf in sorted(ranked_friends.items(), 
                   key=itemgetter(1), 
                   reverse=True) ]
print "My similar friends (ranked)"
print pt

# Also keep in mind that you have the full range of plotting
# capabilities available to you. A quick histogram that shows
# how many friends.

plt.hist(ranked_friends.values())
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')

# Keep in mind that you can customize the binning
# as desired. See http://matplotlib.org/api/pyplot_api.html

# For example...

plt.figure() # Display the previous plot
plt.hist(ranked_friends.values(),
          bins=arange(1,max(ranked_friends.values()),1))
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')
plt.figure() # Display the working plot
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-b2791a7700c5> in <module>()
#      39 plt.figure() # Display the previous plot
#      40 plt.hist(ranked_friends.values(),
# ---> 41           bins=arange(1,max(ranked_friends.values()),1))
#      42 plt.xlabel('Bins (number of friends with shared likes)')
#      43 plt.ylabel('Number of shared likes in each bin')
#
# /Users/kbrooks/anaconda/python.app/Contents/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2825                       histtype=histtype, align=align, orientation=orientation,
#    2826                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2827                       stacked=stacked, **kwargs)
#    2828         draw_if_interactive()
#    2829     finally:
#
# /Users/kbrooks/anaconda/python.app/Contents/lib/python2.7/site-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8322             # this will automatically overwrite bins,
#    8323             # so that each histogram uses the same bins
# -> 8324             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    8325             m = m.astype(float) # causes problems later if it's an int
#    8326             if mlast is None:
#
# /Users/kbrooks/anaconda/python.app/Contents/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     192             sa = sort(a[i:i+block])
#     193             n += np.r_[sa.searchsorted(bins[:-1], 'left'), \
# --> 194                 sa.searchsorted(bins[-1], 'right')]
#     195     else:
#     196         zero = array(0, dtype=ntype)
#
# IndexError: index -1 is out of bounds for axis 0 with size 0
# My similar friends (ranked)
# +--------------------+--------------+
# | Friend             | Common Likes |
# +--------------------+--------------+
# | Kari Paulson       |            1 |
# | Piero Chiodo       |            1 |
# | Thierry Brethes    |            1 |
# | J. Kirby Best      |            1 |
# | Stephen James Cole |            1 |
# | John Warren        |            1 |
# +--------------------+--------------+

# %% [markdown]
# ## Example 13. Constructing a graph of mutual friendships

# %%
import networkx as nx # pip install networkx
import requests # pip install requests

friends = [ (friend['id'], friend['name'],)
                for friend in g.get_connections('me', 'friends')['data'] ]

url = 'https://graph.facebook.com/me/mutualfriends/%s?access_token=%s'

mutual_friends = {} 

# This loop spawns a separate request for each iteration, so
# it may take a while. Optimization with a thread pool or similar
# technique would be possible.
for friend_id, friend_name in friends:
    r = requests.get(url % (friend_id, ACCESS_TOKEN,) )
    response_data = json.loads(r.content)['data']
    mutual_friends[friend_name] = [ data['name'] 
                                    for data in response_data ]
    
nxg = nx.Graph()

[ nxg.add_edge('me', mf) for mf in mutual_friends ]

[ nxg.add_edge(f1, f2) 
  for f1 in mutual_friends 
      for f2 in mutual_friends[f1] ]

# Explore what's possible to do with the graph by 
# typing nxg.<tab> or executing a new cell with 
# the following value in it to see some pydoc on nxg
print nxg

# %% [markdown]
# ## Example 14. Finding and analyzing cliques in a graph of mutual friendships

# %%
# Finding cliques is a hard problem, so this could
# take a while for large graphs.
# See http://en.wikipedia.org/wiki/NP-complete and 
# http://en.wikipedia.org/wiki/Clique_problem.

cliques = [c for c in nx.find_cliques(nxg)]

num_cliques = len(cliques)

clique_sizes = [len(c) for c in cliques]
max_clique_size = max(clique_sizes)
avg_clique_size = sum(clique_sizes) / num_cliques

max_cliques = [c for c in cliques if len(c) == max_clique_size]

num_max_cliques = len(max_cliques)

max_clique_sets = [set(c) for c in max_cliques]
friends_in_all_max_cliques = list(reduce(lambda x, y: x.intersection(y),
                                  max_clique_sets))

print 'Num cliques:', num_cliques
print 'Avg clique size:', avg_clique_size
print 'Max clique size:', max_clique_size
print 'Num max cliques:', num_max_cliques
print
print 'Friends in all max cliques:'
print json.dumps(friends_in_all_max_cliques, indent=1)
print
print 'Max cliques:'
print json.dumps(max_cliques, indent=1)

# %% [markdown]
# ## Example 15. Serializing a NetworkX graph to a file for consumption by D3

# %%
from networkx.readwrite import json_graph

nld = json_graph.node_link_data(nxg)

json.dump(nld, open('resources/ch02-facebook/viz/force.json','w'))

# %% [markdown]
# Note: You may need to implement some filtering on the NetworkX graph before writing it out to a file for display in D3, and for more than dozens of nodes, it may not be reasonable to render a meaningful visualization without some JavaScript hacking on its parameters. View the JavaScript source in [force.html](files/resources/ch02-facebook/viz/force.html) for some of the details.

# %% [markdown]
# ## Example 16. Visualizing a mutual friendship graph with D3

# %%
from IPython.display import IFrame
from IPython.core.display import display

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix.

viz_file = 'files/resources/ch02-facebook/viz/force.html'

display(IFrame(viz_file, '100%', '600px'))
